# %%
from sklearn.datasets import make_regression
import numpy as np
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn as sk
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib as mpl
from ipykernel import kernelapp as app
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df0 = pd.read_csv('~/GitHub/fc_team_project2/datasets/lcdf2.csv')

# %%
int_col = df0.dtypes[df0.dtypes =="int64"].index
int_col = u'loan_amnt', u'delinq_2yrs', u'open_acc', u'pub_rec',
       u'revol_bal', u'total_acc', u'collections_12_mths_ex_med',
       u'policy_code', u'acc_now_delinq', u'tot_coll_amt', u'tot_cur_bal',
       u'total_rev_hi_lim', u'acc_open_past_24mths', u'avg_cur_bal',
       u'chargeoff_within_12_mths', u'delinq_amnt', u'mo_sin_old_rev_tl_op',
       u'mo_sin_rcnt_rev_tl_op', u'mo_sin_rcnt_tl', u'mort_acc',
       u'num_accts_ever_120_pd', u'num_actv_bc_tl', u'num_actv_rev_tl',
       u'num_bc_sats', u'num_bc_tl', u'num_il_tl', u'num_op_rev_tl',
       u'num_rev_accts', u'num_rev_tl_bal_gt_0', u'num_sats', u'num_tl_30dpd',
       u'num_tl_90g_dpd_24m', u'num_tl_op_past_12m', u'pub_rec_bankruptcies',
       u'tax_liens', u'tot_hi_cred_lim', u'total_bal_ex_mort',
       u'total_bc_limit', u'total_il_high_credit_limit'
# Out:
# Index([u'Unnamed: 0', u'loan_amnt', u'delinq_2yrs', u'open_acc', u'pub_rec',
#        u'revol_bal', u'total_acc', u'collections_12_mths_ex_med',
#        u'policy_code', u'acc_now_delinq', u'tot_coll_amt', u'tot_cur_bal',
#        u'total_rev_hi_lim', u'acc_open_past_24mths', u'avg_cur_bal',
#        u'chargeoff_within_12_mths', u'delinq_amnt', u'mo_sin_old_rev_tl_op',
#        u'mo_sin_rcnt_rev_tl_op', u'mo_sin_rcnt_tl', u'mort_acc',
#        u'num_accts_ever_120_pd', u'num_actv_bc_tl', u'num_actv_rev_tl',
#        u'num_bc_sats', u'num_bc_tl', u'num_il_tl', u'num_op_rev_tl',
#        u'num_rev_accts', u'num_rev_tl_bal_gt_0', u'num_sats', u'num_tl_30dpd',
#        u'num_tl_90g_dpd_24m', u'num_tl_op_past_12m', u'pub_rec_bankruptcies',
#        u'tax_liens', u'tot_hi_cred_lim', u'total_bal_ex_mort',
#        u'total_bc_limit', u'total_il_high_credit_limit'],
#       dtype='object')

# %%
print(df0.columns)
df0
# Out:
# Index([u'Unnamed: 0', u'loan_amnt', u'term', u'int_rate', u'installment',
#        u'sub_grade', u'home_ownership', u'annual_inc', u'pymnt_plan', u'dti',
#        u'delinq_2yrs', u'inq_last_6mths', u'mths_since_last_delinq',
#        u'mths_since_last_record', u'open_acc', u'pub_rec', u'revol_bal',
#        u'revol_util', u'total_acc', u'out_prncp', u'out_prncp_inv',
#        u'total_pymnt', u'total_pymnt_inv', u'total_rec_prncp',
#        u'total_rec_int', u'total_rec_late_fee', u'recoveries',
#        u'collection_recovery_fee', u'last_pymnt_amnt',
#        u'collections_12_mths_ex_med', u'mths_since_last_major_derog',
#        u'policy_code', u'application_type', u'acc_now_delinq', u'tot_coll_amt',
#        u'tot_cur_bal', u'open_acc_6m', u'open_il_6m', u'open_il_12m',
#        u'open_il_24m', u'mths_since_rcnt_il', u'total_bal_il', u'il_util',
#        u'open_rv_12m', u'open_rv_24m', u'max_bal_bc', u'all_util',
# ...

# %%
pd.options.display.max_columns = 110

# %%
cat = ["loan_amnt", "acc_now_deling", ]

# %%
aaa = df0[int_col]

# %%
(aaa.iloc[2] < 100 )
# Out:
# Unnamed: 0                     True
# loan_amnt                     False
# delinq_2yrs                    True
# open_acc                       True
# pub_rec                        True
# revol_bal                     False
# total_acc                      True
# collections_12_mths_ex_med     True
# policy_code                    True
# acc_now_delinq                 True
# tot_coll_amt                  False
# tot_cur_bal                   False
# total_rev_hi_lim              False
# acc_open_past_24mths           True
# avg_cur_bal                   False
# chargeoff_within_12_mths       True
# delinq_amnt                    True
# mo_sin_old_rev_tl_op          False
# mo_sin_rcnt_rev_tl_op          True
# mo_sin_rcnt_tl                 True
# mort_acc                       True
# num_accts_ever_120_pd          True
# num_actv_bc_tl                 True
# num_actv_rev_tl                True
# num_bc_sats                    True
# num_bc_tl                      True
# ...

# %%
cat = ["loan_amnt","revol_bal", "tot_coll_amt", "tot_cur_bal", "tot_coll_amt", "total_rev_hi_lim", "avg_cur_bal", "mo_sin_old_rev_tl_op", "tot_hi_cred_lim","total_bal_ex_mort","total_bc_limit","total_il_high_credit_limit"]

# %%
# 이자율 실수타입으로 변경
def p2f(x):
    return float(x.strip('%'))/100

df0['int_rate'] = df0.int_rate.map(p2f)

# %%
aa = sm.add_constant(aa)
y = df0.int_rate

# %%
model = sm.OLS( y,aa)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               int_rate   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     5472.
# Date:                Tue, 11 Jul 2017   Prob (F-statistic):               0.00
# Time:                        17:29:28   Log-Likelihood:             6.7727e+05
# No. Observations:              422724   AIC:                        -1.355e+06
# Df Residuals:                  422722   BIC:                        -1.355e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1100      0.000    395.677      0.000       0.109       0.111
# ...

# %%
dfx = pd.DataFrame(df0[tot])
dfx = sm.add_constant(dfx)
# Out:
#         const  tot_coll_amt  tot_cur_bal  tot_hi_cred_lim  total_acc  \
# 0         1.0           350       109019           160515         38
# 1         1.0           157        24618            45139         18
# 2         1.0          2124       156318           200449         14
# 3         1.0             0        26867            33626          8
# 4         1.0           734        39061            61807         17
# 5         1.0             0        31939            44131          8
# 6         1.0             0       169406           198293         14
# 7         1.0             0        29275            45700         20
# 8         1.0             0       135503           158669         25
# 9         1.0             0        31532            51246         26
# 10        1.0            95        54475           110006         14
# 11        1.0             0       215627           293702         27
# 12        1.0             0        49694            80574         30
# ...

# %%
model = sm.OLS(y,dfx)
result = model.fit()
print (result.summary())
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-106-0e28f31084d2> in <module>()
#       1 model = sm.OLS(y,dfx)
# ----> 2 result = model.fit()
#       3 print (result.summary())
#
# C:\ProgramData\Anaconda2\lib\site-packages\statsmodels\regression\linear_model.pyc in fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     188                 (not hasattr(self, 'rank'))):
#     189
# --> 190                 self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     191                 self.normalized_cov_params = np.dot(self.pinv_wexog,
#     192                                         np.transpose(self.pinv_wexog))
#
# C:\ProgramData\Anaconda2\lib\site-packages\statsmodels\tools\tools.pyc in pinv_extended(X, rcond)
#     340     X = np.asarray(X)
#     341     X = X.conjugate()
# --> 342     u, s, vt = np.linalg.svd(X, 0)
# ...

# %%
#칼럼중 신용 관련된 한계치들 따로 뽑아냄
tot = ['tot_coll_amt','tot_cur_bal','tot_hi_cred_lim','total_acc','total_bal_ex_mort','total_bal_il','total_bc_limit','total_cu_tl','total_il_high_credit_limit','total_pymnt','total_pymnt_inv','total_rec_int','total_rec_late_fee','total_rec_prncp','total_rev_hi_lim']
tot1 = ['tot_coll_amt','tot_cur_bal','tot_hi_cred_lim']
tot2 = ['annual_inc','tot_coll_amt', 'tot_cur_bal', 'tot_hi_cred_lim', 'total_rec_late_fee']
sns.pairplot(df0[tot1])
plt.show()

# %%
aa = df0.tot_cur_bal/df0.tot_hi_cred_lim
y = df0.["int_rate"]
# Out:
#   File "<ipython-input-109-7bd474796ff7>", line 2
#     y = df0.["int_rate"]
#             ^
# SyntaxError: invalid syntax

# %%
sns.jointplot(df0.tot_hi_cred_lim.value_counts().index,df0.tot_hi_cred_lim.value_counts())
plt.show()
df0.tot_hi_cred_lim.value_counts()
# Out:
# 15000     136
# 14800     131
# 21000     129
# 24000     129
# 22000     128
# 17300     126
# 19000     126
# 18200     125
# 28000     122
# 18000     122
# 23100     122
# 19500     121
# 15500     119
# 14500     118
# 14000     118
# 20000     117
# 17700     117
# 20800     117
# 16000     115
# 23200     115
# 17500     115
# 12300     114
# 14900     114
# 13800     114
# 11500     114
# 19800     114
# 20300     113
# 12500     113
# 17000     113
# 22300     111
#          ...
# 266266      1
# 286740      1
# 309263      1
# 303116      1
# 325639      1
# 323590      1
# 438350      1
# 677392      1
# 82096       1
# 424023      1
# 110766      1
# 106668      1
# 102570      1
# 622760      1
# 129191      1
# 118946      1
# 4250        1
# 526489      1
# 20626       1
# 18577       1
# 16528       1
# 467068      1
# 989307      1
# 458872      1
# 481395      1
# 491624      1
# 516196      1
# 512098      1
# 395353      1
# 526337      1
# ...

# %%
plt.plot(df0.tot_hi_cred_lim)
plt.show()

# %%
tot2 = ['annual_inc','tot_coll_amt', 'tot_cur_bal', 'tot_hi_cred_lim', 'total_rec_late_fee']
sns.pairplot(df0[tot2])
plt.show()

# %%
df1 = pd.DataFrame([])
df1["ratio"] = df0.tot_hi_cred_lim / df0.tot_cur_bal

# %%
plt.plot(df1)
plt.show()
df_sp = df0.loc[(df1["ratio"] > 5000),:]

# %%
pd.options.display.max_columns = 110
a = df_sp.describe().std()
b = df0.describe().std()

# %%
# Out:
# array([  1.44450613e+05,   1.26782156e+04,   2.22286879e+01,
#          3.63072188e+02,   4.05190051e+04,   2.20761995e+01,
#          2.21079691e+01,   2.19975082e+01,   2.13048594e+01,
#          2.99840390e+01,   2.06671425e+01,   2.21407157e+01,
#          2.19888702e+01,   2.21852848e+01,   1.10849645e+04,
#          1.10849662e+04,   9.63408278e+03,   9.63409593e+03,
#          9.68915639e+03,   2.32650482e+03,   2.22352323e+01,
#          2.22738636e+01,   2.22738636e+01,   1.01793513e+04,
#          2.22188589e+01,   2.42074576e+01,   2.19736043e+01,
#          2.22738636e+01,   3.10617035e+03,   2.19888702e+01,
#          2.20859661e+01,   2.22738636e+01,   2.21454830e+01,
#          2.19883187e+01,   9.35775895e+01,   2.22738636e+01,
#          7.07106781e-01,   2.19369119e+01,   2.15141320e+01,
#          2.19888702e+01,   2.22738636e+01,   2.66631290e+04,
#          2.19801969e+01,   2.18559381e+01,   2.16605881e+01,
# ...

# %%
plt.plot(b.values/a.values)
plt.show()

# %%
df0.describe()
# Out:
#           Unnamed: 0      loan_amnt       int_rate    installment  \
# count  422724.000000  422724.000000  422724.000000  422724.000000
# mean   217293.118202   14630.686334       0.129775     441.057998
# std    124984.194768    8958.074782       0.049062     269.719847
# min         0.000000    1000.000000       0.053200      30.120000
# 25%    109502.750000    7800.000000       0.091700     245.160000
# 50%    217846.500000   12000.000000       0.119900     372.670000
# 75%    324546.250000   20000.000000       0.153100     587.170000
# max    434406.000000   40000.000000       0.309900    1584.900000
#
#          annual_inc            dti    delinq_2yrs  inq_last_6mths  \
# count  4.227240e+05  422724.000000  422724.000000   422723.000000
# mean   8.008217e+04      18.476746       0.360708        0.562136
# std    7.804732e+04       8.346842       0.949153        0.862449
# min    4.800000e+03      -1.000000       0.000000        0.000000
# ...

# %%
df_sp.describe()
# Out:
#           Unnamed: 0     loan_amnt   int_rate  installment     annual_inc  \
# count      63.000000     63.000000  63.000000    63.000000      63.000000
# mean   201638.412698  12082.936508   0.137638   380.568730   59912.610794
# std    118076.977434   9406.064475   0.059913   293.695391   30232.107712
# min      4119.000000   1275.000000   0.053200    50.020000   17500.000000
# 25%    118505.000000   5000.000000   0.091600   176.595000   36900.000000
# 50%    192124.000000   9600.000000   0.119900   303.730000   55000.000000
# 75%    301374.500000  16750.000000   0.181200   452.590000   76500.000000
# max    426066.000000  40000.000000   0.252900  1189.680000  131000.000000
#
#              dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# count  63.000000    63.000000       63.000000               23.000000
# mean    0.127143     0.190476        0.460317               35.521739
# std     0.575341     0.563890        0.799706               21.381533
# ...

# %%
df_sp
# Out:
#         Unnamed: 0  loan_amnt        term  int_rate  installment sub_grade  \
# 4009          4119      10000   36 months    0.1147       329.62        B5
# 11317        11705       6500   36 months    0.0975       208.98        B3
# 14011        14501      28000   36 months    0.0532       843.22        A1
# 14778        15287       7500   36 months    0.1899       274.89        D4
# 20238        20945       4000   36 months    0.0697       123.46        A3
# 23360        24185       7000   36 months    0.0916       223.12        B2
# 25233        26124      17500   60 months    0.1199       389.19        C1
# 25487        26386      24000   36 months    0.1299       808.54        C2
# 34003        35244       5000   36 months    0.0697       154.32        A3
# 36150        37466      27550   60 months    0.0975       581.98        B3
# 67760        70196       8000   36 months    0.0916       255.00        B2
# ...
