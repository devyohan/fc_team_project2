# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
# Out:
# C:\Users\Ryoo\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df0 = pd.read_csv('lcdf3.csv')

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
df0.head()
# Out:
#    loan_amnt        term  int_rate  installment sub_grade home_ownership  \
# 0      16000   60 months    0.0975       337.99        B3            OWN
# 1       6000   36 months    0.0739       186.34        A4       MORTGAGE
# 2       5625   36 months    0.1825       204.07        D3       MORTGAGE
# 3       6000   36 months    0.1075       195.73        B4           RENT
# 4      10000   36 months    0.0839       315.17        B1           RENT
#
#    annual_inc pymnt_plan    dti  delinq_2yrs  inq_last_6mths  \
# 0    120000.0          n  13.68            1             0.0
# 1     72000.0          n  10.68            0             0.0
# 2     53328.0          n  10.51            0             0.0
# 3     35000.0          n  20.58            0             0.0
# 4     48000.0          n  29.58            0             0.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    20.0                     NaN        25        0
# 1                     NaN                     NaN        12        0
# 2                    67.0                     NaN         7        0
# 3                     NaN                     NaN         7        0
# 4                     NaN                    25.0        13        1
#
#    revol_bal  revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  \
# 0      16763       0.305         38   13160.31       13160.31  4376.540000
# 1       5426       0.236         18       0.00           0.00  6369.416519
# 2       1773       0.269         14    3935.46        3935.46  2655.450000
# 3       3691       0.753          8    4051.72        4051.72  2537.320000
# 4       7089       0.521         17    6674.47        6674.47  4087.890000
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          4376.54          2839.69        1536.85                 0.0
# 1          6369.42          6000.00         369.42                 0.0
# 2          2655.45          1689.54         965.91                 0.0
# 3          2537.32          1948.28         589.04                 0.0
# 4          4087.89          3325.53         762.36                 0.0
#
#    recoveries  collection_recovery_fee  last_pymnt_amnt  \
# 0         0.0                      0.0           337.99
# 1         0.0                      0.0          4510.95
# 2         0.0                      0.0           204.07
# 3         0.0                      0.0           195.73
# 4         0.0                      0.0           315.17
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                           1                         53.0            1
# 1                           0                          NaN            1
# 2                           0                          NaN            1
# 3                           0                          NaN            1
# 4                           0                          NaN            1
#
#   application_type  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  \
# 0       INDIVIDUAL               0           350       109019          2.0
# 1       INDIVIDUAL               0           157        24618          0.0
# 2       INDIVIDUAL               0          2124       156318          3.0
# 3       INDIVIDUAL               0             0        26867          1.0
# 4       INDIVIDUAL               0           734        39061          0.0
#
#    open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  \
# 0         3.0          2.0          2.0                 2.0       25781.0
# 1         5.0          1.0          1.0                 7.0       19192.0
# 2         1.0          1.0          3.0                 3.0        7560.0
# 3         1.0          0.0          1.0                16.0       23176.0
# 4         3.0          0.0          1.0                23.0       31972.0
#
#    il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 0     68.0          1.0          7.0      4244.0      46.0             54900
# 1     87.0          0.0          3.0      3147.0      55.0             23000
# 2     98.0          3.0          5.0       361.0      65.0              6600
# 3     81.0          3.0          5.0       872.0      80.0              4900
# 4     66.0          1.0          2.0      2987.0      63.0             13600
#
#    inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0     5.0          1.0          11.0                    11         4542
# 1     0.0          3.0           2.0                     4         2052
# 2     0.0          1.0           0.0                     8        22331
# 3     1.0          0.0           0.0                     6         3838
# 4     2.0          4.0           0.0                     3         3255
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0         12857.0     48.6                         0            0
# 1          4158.0     55.8                         0            0
# 2          1809.0     30.4                         0            0
# 3           334.0     84.1                         0            0
# 4          2327.0     59.9                         0            0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0               157.0                   256                     12
# 1                89.0                    84                     14
# 2               121.0                   132                      2
# 3                16.0                   130                      3
# 4                48.0                    41                      7
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0               2         1                  14.0                       NaN
# 1               7         0                  14.0                       NaN
# 2               2         1                   2.0                      81.0
# 3               3         0                  10.0                       NaN
# 4               7         0                  31.0                       NaN
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    2.0                            20.0
# 1                    9.0                             NaN
# 2                   14.0                            81.0
# 3                   16.0                             NaN
# 4                   18.0                             NaN
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                      1               5               13            6
# 1                      0               2                4            2
# 2                      0               3                4            3
# 3                      0               3                6            3
# 4                      0               2                7            2
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0         10          8             19             28                   13
# 1          4          8              7             10                    4
# 2          4          7              5              6                    4
# 3          3          1              6              7                    6
# 4          2          4             10             13                    7
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0        25               0.0             0                   0
# 1        12               0.0             0                   0
# 2         7               0.0             0                   0
# 3         7               0.0             0                   0
# 4        13               0.0             0                   0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                   5            94.6              16.7                     0
# 1                   1           100.0               0.0                     0
# 2                   4            84.6               0.0                     0
# 3                   3           100.0             100.0                     0
# 4                   1           100.0               0.0                     0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          0           160515              42544           25000
# 1          0            45139              24618            9400
# 2          0           200449               9333            2600
# 3          0            33626              26867            2100
# 4          0            61807              39061            5800
#
#    total_il_high_credit_limit
# 0                       38196
# 1                       22139
# 2                        7704
# 3                       28726
# 4                       48207

# %%
df0corr = df0.corr()
df0corr.shape

# %%
df0corr[(df0corr >= 0.8) | (df0corr <= -0.8)].fillna('')
# Out:
#                                loan_amnt int_rate installment annual_inc dti  \
# loan_amnt                              1             0.950004
# int_rate                                        1
# installment                     0.950004                    1
# annual_inc                                                             1
# dti                                                                        1
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                delinq_2yrs inq_last_6mths  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs                              1
# inq_last_6mths                                          1
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                mths_since_last_delinq mths_since_last_record  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq                              1
# mths_since_last_record                                                     1
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq               0.859438
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                 open_acc pub_rec revol_bal revol_util  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc                               1
# pub_rec                                        1
# revol_bal                                                1
# revol_util                                                          1
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim                                  0.833575
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util                                                      0.858375
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl                   0.833676
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats                        0.998651
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                total_acc out_prncp out_prncp_inv total_pymnt  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc                              1
# out_prncp                                        1      0.999995
# out_prncp_inv                             0.999995             1
# total_pymnt                                                                1
# total_pymnt_inv                                                     0.999996
# total_rec_prncp                                                     0.976723
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt                                                     0.814659
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                total_pymnt_inv total_rec_prncp total_rec_int  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt                           0.999996        0.976723
# total_pymnt_inv                              1        0.976716
# total_rec_prncp                       0.976716               1
# total_rec_int                                                              1
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt                        0.81466         0.86936
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                total_rec_late_fee recoveries  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee                              1
# recoveries                                                 1
# collection_recovery_fee                             0.933082
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                collection_recovery_fee last_pymnt_amnt  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt                                                   0.814659
# total_pymnt_inv                                                0.81466
# total_rec_prncp                                                0.86936
# total_rec_int
# total_rec_late_fee
# recoveries                                    0.933082
# collection_recovery_fee                              1
# last_pymnt_amnt                                                      1
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# ...
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util                                0.845079
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75                              1
# pub_rec_bankruptcies                                               1
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal                                     0.971236
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il                                                      0.893174
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens                              1
# tot_hi_cred_lim                                        1
# total_bal_ex_mort                                                        1
# total_bc_limit
# total_il_high_credit_limit                                        0.879395
#
#                                total_bc_limit total_il_high_credit_limit
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il                                                    0.956908
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy                       0.823009
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort                                               0.879395
# total_bc_limit                              1
# total_il_high_credit_limit                                             1

# %%
df0.drop(['out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'collections_12_mths_ex_med'], axis=1, inplace=True)

# %%
df0corr = df0.corr()

# %%
df0corr[(df0corr >= 0.8) | (df0corr <= -0.8)].fillna('')
# Out:
#                                loan_amnt int_rate installment annual_inc dti  \
# loan_amnt                              1             0.950004
# int_rate                                        1
# installment                     0.950004                    1
# annual_inc                                                             1
# dti                                                                        1
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                delinq_2yrs inq_last_6mths  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs                              1
# inq_last_6mths                                          1
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                mths_since_last_delinq mths_since_last_record  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq                              1
# mths_since_last_record                                                     1
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq               0.859438
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                 open_acc pub_rec revol_bal revol_util  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc                               1
# pub_rec                                        1
# revol_bal                                                1
# revol_util                                                          1
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim                                  0.833575
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util                                                      0.858375
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl                   0.833676
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats                        0.998651
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                total_acc last_pymnt_amnt  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc                              1
# last_pymnt_amnt                                        1
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                mths_since_last_major_derog policy_code  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog                              1
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                acc_now_delinq tot_coll_amt tot_cur_bal  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq                              1
# tot_coll_amt                                             1
# tot_cur_bal                                                          1
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal                                                   0.832944
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd                         0.811237
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim                                               0.971236
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                open_acc_6m open_il_6m open_il_12m open_il_24m  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m                              1
# open_il_6m                                          1
# open_il_12m                                                     1
# open_il_24m                                                                 1
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                mths_since_rcnt_il total_bal_il il_util  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il                              1
# total_bal_il                                                 1
# il_util                                                              1
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort                                     0.893174
# total_bc_limit
# total_il_high_credit_limit                            0.956908
#
# ...
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util                                0.845079
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75                              1
# pub_rec_bankruptcies                                               1
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal                                     0.971236
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il                                                      0.893174
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens                              1
# tot_hi_cred_lim                                        1
# total_bal_ex_mort                                                        1
# total_bc_limit
# total_il_high_credit_limit                                        0.879395
#
#                                total_bc_limit total_il_high_credit_limit
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il                                                    0.956908
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy                       0.823009
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort                                               0.879395
# total_bc_limit                              1
# total_il_high_credit_limit                                             1

# %%
df1 = df0.drop(['loan_amnt', 'mths_since_last_delinq', 'mths_since_last_record', 'last_pymnt_amnt', 'open_acc', 'revol_util', 'revol_bal', 'acc_now_delinq', 'tot_cur_bal', 'total_bal_il', 'open_rv_12m' ,'open_rv_24m', 'bc_open_to_buy', 'bc_util', 'mths_since_recent_bc_dlq', 'num_actv_bc_tl', 'num_bc_tl', 'num_op_rev_tl', 'total_bal_ex_mort', 'num_actv_rev_tl'], axis=1)

# %%
df1.corr()[(df1.corr() >= 0.8) | (df1.corr() <= -0.8)]
# Out:
#                                 int_rate  installment  annual_inc  dti  \
# int_rate                             1.0          NaN         NaN  NaN
# installment                          NaN          1.0         NaN  NaN
# annual_inc                           NaN          NaN         1.0  NaN
# dti                                  NaN          NaN         NaN  1.0
# delinq_2yrs                          NaN          NaN         NaN  NaN
# inq_last_6mths                       NaN          NaN         NaN  NaN
# pub_rec                              NaN          NaN         NaN  NaN
# total_acc                            NaN          NaN         NaN  NaN
# mths_since_last_major_derog          NaN          NaN         NaN  NaN
# policy_code                          NaN          NaN         NaN  NaN
# tot_coll_amt                         NaN          NaN         NaN  NaN
# open_acc_6m                          NaN          NaN         NaN  NaN
# open_il_6m                           NaN          NaN         NaN  NaN
# open_il_12m                          NaN          NaN         NaN  NaN
# open_il_24m                          NaN          NaN         NaN  NaN
# mths_since_rcnt_il                   NaN          NaN         NaN  NaN
# il_util                              NaN          NaN         NaN  NaN
# max_bal_bc                           NaN          NaN         NaN  NaN
# all_util                             NaN          NaN         NaN  NaN
# total_rev_hi_lim                     NaN          NaN         NaN  NaN
# inq_fi                               NaN          NaN         NaN  NaN
# total_cu_tl                          NaN          NaN         NaN  NaN
# inq_last_12m                         NaN          NaN         NaN  NaN
# acc_open_past_24mths                 NaN          NaN         NaN  NaN
# avg_cur_bal                          NaN          NaN         NaN  NaN
# chargeoff_within_12_mths             NaN          NaN         NaN  NaN
# delinq_amnt                          NaN          NaN         NaN  NaN
# mo_sin_old_il_acct                   NaN          NaN         NaN  NaN
# mo_sin_old_rev_tl_op                 NaN          NaN         NaN  NaN
# mo_sin_rcnt_rev_tl_op                NaN          NaN         NaN  NaN
# mo_sin_rcnt_tl                       NaN          NaN         NaN  NaN
# mort_acc                             NaN          NaN         NaN  NaN
# mths_since_recent_bc                 NaN          NaN         NaN  NaN
# mths_since_recent_inq                NaN          NaN         NaN  NaN
# mths_since_recent_revol_delinq       NaN          NaN         NaN  NaN
# num_accts_ever_120_pd                NaN          NaN         NaN  NaN
# num_bc_sats                          NaN          NaN         NaN  NaN
# num_il_tl                            NaN          NaN         NaN  NaN
# num_rev_accts                        NaN          NaN         NaN  NaN
# num_rev_tl_bal_gt_0                  NaN          NaN         NaN  NaN
# num_sats                             NaN          NaN         NaN  NaN
# num_tl_120dpd_2m                     NaN          NaN         NaN  NaN
# num_tl_30dpd                         NaN          NaN         NaN  NaN
# num_tl_90g_dpd_24m                   NaN          NaN         NaN  NaN
# num_tl_op_past_12m                   NaN          NaN         NaN  NaN
# pct_tl_nvr_dlq                       NaN          NaN         NaN  NaN
# percent_bc_gt_75                     NaN          NaN         NaN  NaN
# pub_rec_bankruptcies                 NaN          NaN         NaN  NaN
# tax_liens                            NaN          NaN         NaN  NaN
# tot_hi_cred_lim                      NaN          NaN         NaN  NaN
# total_bc_limit                       NaN          NaN         NaN  NaN
# total_il_high_credit_limit           NaN          NaN         NaN  NaN
#
#                                 delinq_2yrs  inq_last_6mths  pub_rec  \
# int_rate                                NaN             NaN      NaN
# installment                             NaN             NaN      NaN
# annual_inc                              NaN             NaN      NaN
# dti                                     NaN             NaN      NaN
# delinq_2yrs                             1.0             NaN      NaN
# inq_last_6mths                          NaN             1.0      NaN
# pub_rec                                 NaN             NaN      1.0
# total_acc                               NaN             NaN      NaN
# mths_since_last_major_derog             NaN             NaN      NaN
# policy_code                             NaN             NaN      NaN
# tot_coll_amt                            NaN             NaN      NaN
# open_acc_6m                             NaN             NaN      NaN
# open_il_6m                              NaN             NaN      NaN
# open_il_12m                             NaN             NaN      NaN
# open_il_24m                             NaN             NaN      NaN
# mths_since_rcnt_il                      NaN             NaN      NaN
# il_util                                 NaN             NaN      NaN
# max_bal_bc                              NaN             NaN      NaN
# all_util                                NaN             NaN      NaN
# total_rev_hi_lim                        NaN             NaN      NaN
# inq_fi                                  NaN             NaN      NaN
# total_cu_tl                             NaN             NaN      NaN
# inq_last_12m                            NaN             NaN      NaN
# acc_open_past_24mths                    NaN             NaN      NaN
# avg_cur_bal                             NaN             NaN      NaN
# chargeoff_within_12_mths                NaN             NaN      NaN
# delinq_amnt                             NaN             NaN      NaN
# mo_sin_old_il_acct                      NaN             NaN      NaN
# mo_sin_old_rev_tl_op                    NaN             NaN      NaN
# mo_sin_rcnt_rev_tl_op                   NaN             NaN      NaN
# mo_sin_rcnt_tl                          NaN             NaN      NaN
# mort_acc                                NaN             NaN      NaN
# mths_since_recent_bc                    NaN             NaN      NaN
# mths_since_recent_inq                   NaN             NaN      NaN
# mths_since_recent_revol_delinq          NaN             NaN      NaN
# num_accts_ever_120_pd                   NaN             NaN      NaN
# num_bc_sats                             NaN             NaN      NaN
# num_il_tl                               NaN             NaN      NaN
# num_rev_accts                           NaN             NaN      NaN
# num_rev_tl_bal_gt_0                     NaN             NaN      NaN
# num_sats                                NaN             NaN      NaN
# num_tl_120dpd_2m                        NaN             NaN      NaN
# num_tl_30dpd                            NaN             NaN      NaN
# num_tl_90g_dpd_24m                      NaN             NaN      NaN
# num_tl_op_past_12m                      NaN             NaN      NaN
# pct_tl_nvr_dlq                          NaN             NaN      NaN
# percent_bc_gt_75                        NaN             NaN      NaN
# pub_rec_bankruptcies                    NaN             NaN      NaN
# tax_liens                               NaN             NaN      NaN
# tot_hi_cred_lim                         NaN             NaN      NaN
# total_bc_limit                          NaN             NaN      NaN
# total_il_high_credit_limit              NaN             NaN      NaN
#
#                                 total_acc  mths_since_last_major_derog  \
# int_rate                              NaN                          NaN
# installment                           NaN                          NaN
# annual_inc                            NaN                          NaN
# dti                                   NaN                          NaN
# delinq_2yrs                           NaN                          NaN
# inq_last_6mths                        NaN                          NaN
# pub_rec                               NaN                          NaN
# total_acc                             1.0                          NaN
# mths_since_last_major_derog           NaN                          1.0
# policy_code                           NaN                          NaN
# tot_coll_amt                          NaN                          NaN
# open_acc_6m                           NaN                          NaN
# open_il_6m                            NaN                          NaN
# open_il_12m                           NaN                          NaN
# open_il_24m                           NaN                          NaN
# mths_since_rcnt_il                    NaN                          NaN
# il_util                               NaN                          NaN
# max_bal_bc                            NaN                          NaN
# all_util                              NaN                          NaN
# total_rev_hi_lim                      NaN                          NaN
# inq_fi                                NaN                          NaN
# total_cu_tl                           NaN                          NaN
# inq_last_12m                          NaN                          NaN
# acc_open_past_24mths                  NaN                          NaN
# avg_cur_bal                           NaN                          NaN
# chargeoff_within_12_mths              NaN                          NaN
# delinq_amnt                           NaN                          NaN
# mo_sin_old_il_acct                    NaN                          NaN
# mo_sin_old_rev_tl_op                  NaN                          NaN
# mo_sin_rcnt_rev_tl_op                 NaN                          NaN
# mo_sin_rcnt_tl                        NaN                          NaN
# mort_acc                              NaN                          NaN
# mths_since_recent_bc                  NaN                          NaN
# mths_since_recent_inq                 NaN                          NaN
# mths_since_recent_revol_delinq        NaN                          NaN
# num_accts_ever_120_pd                 NaN                          NaN
# num_bc_sats                           NaN                          NaN
# num_il_tl                             NaN                          NaN
# num_rev_accts                         NaN                          NaN
# num_rev_tl_bal_gt_0                   NaN                          NaN
# num_sats                              NaN                          NaN
# num_tl_120dpd_2m                      NaN                          NaN
# num_tl_30dpd                          NaN                          NaN
# num_tl_90g_dpd_24m                    NaN                          NaN
# num_tl_op_past_12m                    NaN                          NaN
# pct_tl_nvr_dlq                        NaN                          NaN
# percent_bc_gt_75                      NaN                          NaN
# pub_rec_bankruptcies                  NaN                          NaN
# tax_liens                             NaN                          NaN
# tot_hi_cred_lim                       NaN                          NaN
# total_bc_limit                        NaN                          NaN
# total_il_high_credit_limit            NaN                          NaN
#
#                                 policy_code  tot_coll_amt  open_acc_6m  \
# int_rate                                NaN           NaN          NaN
# installment                             NaN           NaN          NaN
# annual_inc                              NaN           NaN          NaN
# dti                                     NaN           NaN          NaN
# delinq_2yrs                             NaN           NaN          NaN
# inq_last_6mths                          NaN           NaN          NaN
# pub_rec                                 NaN           NaN          NaN
# total_acc                               NaN           NaN          NaN
# mths_since_last_major_derog             NaN           NaN          NaN
# policy_code                             NaN           NaN          NaN
# tot_coll_amt                            NaN           1.0          NaN
# open_acc_6m                             NaN           NaN          1.0
# open_il_6m                              NaN           NaN          NaN
# open_il_12m                             NaN           NaN          NaN
# open_il_24m                             NaN           NaN          NaN
# mths_since_rcnt_il                      NaN           NaN          NaN
# il_util                                 NaN           NaN          NaN
# max_bal_bc                              NaN           NaN          NaN
# all_util                                NaN           NaN          NaN
# total_rev_hi_lim                        NaN           NaN          NaN
# inq_fi                                  NaN           NaN          NaN
# total_cu_tl                             NaN           NaN          NaN
# inq_last_12m                            NaN           NaN          NaN
# acc_open_past_24mths                    NaN           NaN          NaN
# avg_cur_bal                             NaN           NaN          NaN
# chargeoff_within_12_mths                NaN           NaN          NaN
# delinq_amnt                             NaN           NaN          NaN
# mo_sin_old_il_acct                      NaN           NaN          NaN
# mo_sin_old_rev_tl_op                    NaN           NaN          NaN
# mo_sin_rcnt_rev_tl_op                   NaN           NaN          NaN
# mo_sin_rcnt_tl                          NaN           NaN          NaN
# mort_acc                                NaN           NaN          NaN
# mths_since_recent_bc                    NaN           NaN          NaN
# mths_since_recent_inq                   NaN           NaN          NaN
# mths_since_recent_revol_delinq          NaN           NaN          NaN
# num_accts_ever_120_pd                   NaN           NaN          NaN
# num_bc_sats                             NaN           NaN          NaN
# num_il_tl                               NaN           NaN          NaN
# num_rev_accts                           NaN           NaN          NaN
# num_rev_tl_bal_gt_0                     NaN           NaN          NaN
# num_sats                                NaN           NaN          NaN
# num_tl_120dpd_2m                        NaN           NaN          NaN
# num_tl_30dpd                            NaN           NaN          NaN
# num_tl_90g_dpd_24m                      NaN           NaN          NaN
# num_tl_op_past_12m                      NaN           NaN          NaN
# pct_tl_nvr_dlq                          NaN           NaN          NaN
# percent_bc_gt_75                        NaN           NaN          NaN
# pub_rec_bankruptcies                    NaN           NaN          NaN
# tax_liens                               NaN           NaN          NaN
# tot_hi_cred_lim                         NaN           NaN          NaN
# total_bc_limit                          NaN           NaN          NaN
# total_il_high_credit_limit              NaN           NaN          NaN
#
#                                 open_il_6m  open_il_12m  open_il_24m  \
# int_rate                               NaN          NaN          NaN
# installment                            NaN          NaN          NaN
# annual_inc                             NaN          NaN          NaN
# dti                                    NaN          NaN          NaN
# delinq_2yrs                            NaN          NaN          NaN
# inq_last_6mths                         NaN          NaN          NaN
# pub_rec                                NaN          NaN          NaN
# total_acc                              NaN          NaN          NaN
# mths_since_last_major_derog            NaN          NaN          NaN
# policy_code                            NaN          NaN          NaN
# tot_coll_amt                           NaN          NaN          NaN
# open_acc_6m                            NaN          NaN          NaN
# open_il_6m                             1.0          NaN          NaN
# open_il_12m                            NaN          1.0          NaN
# open_il_24m                            NaN          NaN          1.0
# mths_since_rcnt_il                     NaN          NaN          NaN
# il_util                                NaN          NaN          NaN
# max_bal_bc                             NaN          NaN          NaN
# all_util                               NaN          NaN          NaN
# total_rev_hi_lim                       NaN          NaN          NaN
# inq_fi                                 NaN          NaN          NaN
# total_cu_tl                            NaN          NaN          NaN
# inq_last_12m                           NaN          NaN          NaN
# acc_open_past_24mths                   NaN          NaN          NaN
# avg_cur_bal                            NaN          NaN          NaN
# chargeoff_within_12_mths               NaN          NaN          NaN
# delinq_amnt                            NaN          NaN          NaN
# mo_sin_old_il_acct                     NaN          NaN          NaN
# mo_sin_old_rev_tl_op                   NaN          NaN          NaN
# mo_sin_rcnt_rev_tl_op                  NaN          NaN          NaN
# mo_sin_rcnt_tl                         NaN          NaN          NaN
# mort_acc                               NaN          NaN          NaN
# mths_since_recent_bc                   NaN          NaN          NaN
# mths_since_recent_inq                  NaN          NaN          NaN
# mths_since_recent_revol_delinq         NaN          NaN          NaN
# num_accts_ever_120_pd                  NaN          NaN          NaN
# num_bc_sats                            NaN          NaN          NaN
# num_il_tl                              NaN          NaN          NaN
# num_rev_accts                          NaN          NaN          NaN
# num_rev_tl_bal_gt_0                    NaN          NaN          NaN
# num_sats                               NaN          NaN          NaN
# num_tl_120dpd_2m                       NaN          NaN          NaN
# num_tl_30dpd                           NaN          NaN          NaN
# num_tl_90g_dpd_24m                     NaN          NaN          NaN
# num_tl_op_past_12m                     NaN          NaN          NaN
# pct_tl_nvr_dlq                         NaN          NaN          NaN
# percent_bc_gt_75                       NaN          NaN          NaN
# pub_rec_bankruptcies                   NaN          NaN          NaN
# tax_liens                              NaN          NaN          NaN
# tot_hi_cred_lim                        NaN          NaN          NaN
# total_bc_limit                         NaN          NaN          NaN
# total_il_high_credit_limit             NaN          NaN          NaN
#
#                                 mths_since_rcnt_il  il_util  max_bal_bc  \
# int_rate                                       NaN      NaN         NaN
# installment                                    NaN      NaN         NaN
# annual_inc                                     NaN      NaN         NaN
# dti                                            NaN      NaN         NaN
# delinq_2yrs                                    NaN      NaN         NaN
# inq_last_6mths                                 NaN      NaN         NaN
# pub_rec                                        NaN      NaN         NaN
# total_acc                                      NaN      NaN         NaN
# mths_since_last_major_derog                    NaN      NaN         NaN
# policy_code                                    NaN      NaN         NaN
# tot_coll_amt                                   NaN      NaN         NaN
# open_acc_6m                                    NaN      NaN         NaN
# open_il_6m                                     NaN      NaN         NaN
# open_il_12m                                    NaN      NaN         NaN
# open_il_24m                                    NaN      NaN         NaN
# mths_since_rcnt_il                             1.0      NaN         NaN
# il_util                                        NaN      1.0         NaN
# max_bal_bc                                     NaN      NaN         1.0
# all_util                                       NaN      NaN         NaN
# total_rev_hi_lim                               NaN      NaN         NaN
# inq_fi                                         NaN      NaN         NaN
# total_cu_tl                                    NaN      NaN         NaN
# inq_last_12m                                   NaN      NaN         NaN
# acc_open_past_24mths                           NaN      NaN         NaN
# avg_cur_bal                                    NaN      NaN         NaN
# chargeoff_within_12_mths                       NaN      NaN         NaN
# delinq_amnt                                    NaN      NaN         NaN
# mo_sin_old_il_acct                             NaN      NaN         NaN
# mo_sin_old_rev_tl_op                           NaN      NaN         NaN
# mo_sin_rcnt_rev_tl_op                          NaN      NaN         NaN
# mo_sin_rcnt_tl                                 NaN      NaN         NaN
# mort_acc                                       NaN      NaN         NaN
# mths_since_recent_bc                           NaN      NaN         NaN
# mths_since_recent_inq                          NaN      NaN         NaN
# mths_since_recent_revol_delinq                 NaN      NaN         NaN
# num_accts_ever_120_pd                          NaN      NaN         NaN
# num_bc_sats                                    NaN      NaN         NaN
# num_il_tl                                      NaN      NaN         NaN
# num_rev_accts                                  NaN      NaN         NaN
# num_rev_tl_bal_gt_0                            NaN      NaN         NaN
# num_sats                                       NaN      NaN         NaN
# num_tl_120dpd_2m                               NaN      NaN         NaN
# num_tl_30dpd                                   NaN      NaN         NaN
# num_tl_90g_dpd_24m                             NaN      NaN         NaN
# num_tl_op_past_12m                             NaN      NaN         NaN
# pct_tl_nvr_dlq                                 NaN      NaN         NaN
# percent_bc_gt_75                               NaN      NaN         NaN
# pub_rec_bankruptcies                           NaN      NaN         NaN
# tax_liens                                      NaN      NaN         NaN
# tot_hi_cred_lim                                NaN      NaN         NaN
# total_bc_limit                                 NaN      NaN         NaN
# total_il_high_credit_limit                     NaN      NaN         NaN
#
#                                 all_util  total_rev_hi_lim  inq_fi  \
# int_rate                             NaN               NaN     NaN
# installment                          NaN               NaN     NaN
# annual_inc                           NaN               NaN     NaN
# dti                                  NaN               NaN     NaN
# delinq_2yrs                          NaN               NaN     NaN
# inq_last_6mths                       NaN               NaN     NaN
# pub_rec                              NaN               NaN     NaN
# total_acc                            NaN               NaN     NaN
# mths_since_last_major_derog          NaN               NaN     NaN
# policy_code                          NaN               NaN     NaN
# tot_coll_amt                         NaN               NaN     NaN
# open_acc_6m                          NaN               NaN     NaN
# open_il_6m                           NaN               NaN     NaN
# open_il_12m                          NaN               NaN     NaN
# open_il_24m                          NaN               NaN     NaN
# mths_since_rcnt_il                   NaN               NaN     NaN
# il_util                              NaN               NaN     NaN
# max_bal_bc                           NaN               NaN     NaN
# all_util                             1.0               NaN     NaN
# total_rev_hi_lim                     NaN               1.0     NaN
# inq_fi                               NaN               NaN     1.0
# total_cu_tl                          NaN               NaN     NaN
# inq_last_12m                         NaN               NaN     NaN
# acc_open_past_24mths                 NaN               NaN     NaN
# avg_cur_bal                          NaN               NaN     NaN
# chargeoff_within_12_mths             NaN               NaN     NaN
# delinq_amnt                          NaN               NaN     NaN
# mo_sin_old_il_acct                   NaN               NaN     NaN
# mo_sin_old_rev_tl_op                 NaN               NaN     NaN
# mo_sin_rcnt_rev_tl_op                NaN               NaN     NaN
# mo_sin_rcnt_tl                       NaN               NaN     NaN
# mort_acc                             NaN               NaN     NaN
# mths_since_recent_bc                 NaN               NaN     NaN
# mths_since_recent_inq                NaN               NaN     NaN
# mths_since_recent_revol_delinq       NaN               NaN     NaN
# num_accts_ever_120_pd                NaN               NaN     NaN
# num_bc_sats                          NaN               NaN     NaN
# num_il_tl                            NaN               NaN     NaN
# num_rev_accts                        NaN               NaN     NaN
# num_rev_tl_bal_gt_0                  NaN               NaN     NaN
# num_sats                             NaN               NaN     NaN
# num_tl_120dpd_2m                     NaN               NaN     NaN
# num_tl_30dpd                         NaN               NaN     NaN
# num_tl_90g_dpd_24m                   NaN               NaN     NaN
# num_tl_op_past_12m                   NaN               NaN     NaN
# pct_tl_nvr_dlq                       NaN               NaN     NaN
# percent_bc_gt_75                     NaN               NaN     NaN
# pub_rec_bankruptcies                 NaN               NaN     NaN
# tax_liens                            NaN               NaN     NaN
# tot_hi_cred_lim                      NaN               NaN     NaN
# total_bc_limit                       NaN               NaN     NaN
# total_il_high_credit_limit           NaN               NaN     NaN
#
#                                 total_cu_tl  inq_last_12m  \
# int_rate                                NaN           NaN
# installment                             NaN           NaN
# annual_inc                              NaN           NaN
# dti                                     NaN           NaN
# delinq_2yrs                             NaN           NaN
# inq_last_6mths                          NaN           NaN
# pub_rec                                 NaN           NaN
# total_acc                               NaN           NaN
# mths_since_last_major_derog             NaN           NaN
# policy_code                             NaN           NaN
# tot_coll_amt                            NaN           NaN
# open_acc_6m                             NaN           NaN
# open_il_6m                              NaN           NaN
# open_il_12m                             NaN           NaN
# open_il_24m                             NaN           NaN
# mths_since_rcnt_il                      NaN           NaN
# il_util                                 NaN           NaN
# max_bal_bc                              NaN           NaN
# all_util                                NaN           NaN
# total_rev_hi_lim                        NaN           NaN
# inq_fi                                  NaN           NaN
# total_cu_tl                             1.0           NaN
# inq_last_12m                            NaN           1.0
# acc_open_past_24mths                    NaN           NaN
# avg_cur_bal                             NaN           NaN
# chargeoff_within_12_mths                NaN           NaN
# delinq_amnt                             NaN           NaN
# mo_sin_old_il_acct                      NaN           NaN
# mo_sin_old_rev_tl_op                    NaN           NaN
# mo_sin_rcnt_rev_tl_op                   NaN           NaN
# mo_sin_rcnt_tl                          NaN           NaN
# mort_acc                                NaN           NaN
# mths_since_recent_bc                    NaN           NaN
# mths_since_recent_inq                   NaN           NaN
# mths_since_recent_revol_delinq          NaN           NaN
# num_accts_ever_120_pd                   NaN           NaN
# num_bc_sats                             NaN           NaN
# num_il_tl                               NaN           NaN
# num_rev_accts                           NaN           NaN
# num_rev_tl_bal_gt_0                     NaN           NaN
# num_sats                                NaN           NaN
# num_tl_120dpd_2m                        NaN           NaN
# num_tl_30dpd                            NaN           NaN
# num_tl_90g_dpd_24m                      NaN           NaN
# num_tl_op_past_12m                      NaN           NaN
# pct_tl_nvr_dlq                          NaN           NaN
# percent_bc_gt_75                        NaN           NaN
# pub_rec_bankruptcies                    NaN           NaN
# tax_liens                               NaN           NaN
# tot_hi_cred_lim                         NaN           NaN
# total_bc_limit                          NaN           NaN
# total_il_high_credit_limit              NaN           NaN
#
#                                 acc_open_past_24mths  avg_cur_bal  \
# int_rate                                         NaN          NaN
# installment                                      NaN          NaN
# annual_inc                                       NaN          NaN
# dti                                              NaN          NaN
# delinq_2yrs                                      NaN          NaN
# inq_last_6mths                                   NaN          NaN
# pub_rec                                          NaN          NaN
# total_acc                                        NaN          NaN
# mths_since_last_major_derog                      NaN          NaN
# policy_code                                      NaN          NaN
# tot_coll_amt                                     NaN          NaN
# open_acc_6m                                      NaN          NaN
# open_il_6m                                       NaN          NaN
# open_il_12m                                      NaN          NaN
# open_il_24m                                      NaN          NaN
# mths_since_rcnt_il                               NaN          NaN
# il_util                                          NaN          NaN
# max_bal_bc                                       NaN          NaN
# all_util                                         NaN          NaN
# total_rev_hi_lim                                 NaN          NaN
# inq_fi                                           NaN          NaN
# total_cu_tl                                      NaN          NaN
# inq_last_12m                                     NaN          NaN
# acc_open_past_24mths                             1.0          NaN
# avg_cur_bal                                      NaN          1.0
# chargeoff_within_12_mths                         NaN          NaN
# delinq_amnt                                      NaN          NaN
# mo_sin_old_il_acct                               NaN          NaN
# mo_sin_old_rev_tl_op                             NaN          NaN
# mo_sin_rcnt_rev_tl_op                            NaN          NaN
# mo_sin_rcnt_tl                                   NaN          NaN
# mort_acc                                         NaN          NaN
# mths_since_recent_bc                             NaN          NaN
# mths_since_recent_inq                            NaN          NaN
# mths_since_recent_revol_delinq                   NaN          NaN
# num_accts_ever_120_pd                            NaN          NaN
# num_bc_sats                                      NaN          NaN
# num_il_tl                                        NaN          NaN
# num_rev_accts                                    NaN          NaN
# num_rev_tl_bal_gt_0                              NaN          NaN
# num_sats                                         NaN          NaN
# num_tl_120dpd_2m                                 NaN          NaN
# num_tl_30dpd                                     NaN          NaN
# num_tl_90g_dpd_24m                               NaN          NaN
# num_tl_op_past_12m                               NaN          NaN
# pct_tl_nvr_dlq                                   NaN          NaN
# percent_bc_gt_75                                 NaN          NaN
# pub_rec_bankruptcies                             NaN          NaN
# tax_liens                                        NaN          NaN
# tot_hi_cred_lim                                  NaN          NaN
# total_bc_limit                                   NaN          NaN
# total_il_high_credit_limit                       NaN          NaN
#
#                                 chargeoff_within_12_mths  delinq_amnt  \
# int_rate                                             NaN          NaN
# installment                                          NaN          NaN
# annual_inc                                           NaN          NaN
# dti                                                  NaN          NaN
# delinq_2yrs                                          NaN          NaN
# inq_last_6mths                                       NaN          NaN
# pub_rec                                              NaN          NaN
# total_acc                                            NaN          NaN
# mths_since_last_major_derog                          NaN          NaN
# policy_code                                          NaN          NaN
# tot_coll_amt                                         NaN          NaN
# open_acc_6m                                          NaN          NaN
# open_il_6m                                           NaN          NaN
# open_il_12m                                          NaN          NaN
# open_il_24m                                          NaN          NaN
# mths_since_rcnt_il                                   NaN          NaN
# il_util                                              NaN          NaN
# max_bal_bc                                           NaN          NaN
# all_util                                             NaN          NaN
# total_rev_hi_lim                                     NaN          NaN
# inq_fi                                               NaN          NaN
# total_cu_tl                                          NaN          NaN
# inq_last_12m                                         NaN          NaN
# acc_open_past_24mths                                 NaN          NaN
# avg_cur_bal                                          NaN          NaN
# chargeoff_within_12_mths                             1.0          NaN
# delinq_amnt                                          NaN          1.0
# mo_sin_old_il_acct                                   NaN          NaN
# mo_sin_old_rev_tl_op                                 NaN          NaN
# mo_sin_rcnt_rev_tl_op                                NaN          NaN
# mo_sin_rcnt_tl                                       NaN          NaN
# mort_acc                                             NaN          NaN
# mths_since_recent_bc                                 NaN          NaN
# mths_since_recent_inq                                NaN          NaN
# mths_since_recent_revol_delinq                       NaN          NaN
# num_accts_ever_120_pd                                NaN          NaN
# num_bc_sats                                          NaN          NaN
# num_il_tl                                            NaN          NaN
# num_rev_accts                                        NaN          NaN
# num_rev_tl_bal_gt_0                                  NaN          NaN
# num_sats                                             NaN          NaN
# num_tl_120dpd_2m                                     NaN          NaN
# num_tl_30dpd                                         NaN          NaN
# num_tl_90g_dpd_24m                                   NaN          NaN
# num_tl_op_past_12m                                   NaN          NaN
# pct_tl_nvr_dlq                                       NaN          NaN
# percent_bc_gt_75                                     NaN          NaN
# pub_rec_bankruptcies                                 NaN          NaN
# tax_liens                                            NaN          NaN
# tot_hi_cred_lim                                      NaN          NaN
# total_bc_limit                                       NaN          NaN
# total_il_high_credit_limit                           NaN          NaN
#
#                                 mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# int_rate                                       NaN                   NaN
# installment                                    NaN                   NaN
# annual_inc                                     NaN                   NaN
# dti                                            NaN                   NaN
# delinq_2yrs                                    NaN                   NaN
# inq_last_6mths                                 NaN                   NaN
# pub_rec                                        NaN                   NaN
# total_acc                                      NaN                   NaN
# mths_since_last_major_derog                    NaN                   NaN
# policy_code                                    NaN                   NaN
# tot_coll_amt                                   NaN                   NaN
# open_acc_6m                                    NaN                   NaN
# open_il_6m                                     NaN                   NaN
# open_il_12m                                    NaN                   NaN
# open_il_24m                                    NaN                   NaN
# mths_since_rcnt_il                             NaN                   NaN
# il_util                                        NaN                   NaN
# max_bal_bc                                     NaN                   NaN
# all_util                                       NaN                   NaN
# total_rev_hi_lim                               NaN                   NaN
# inq_fi                                         NaN                   NaN
# total_cu_tl                                    NaN                   NaN
# inq_last_12m                                   NaN                   NaN
# acc_open_past_24mths                           NaN                   NaN
# avg_cur_bal                                    NaN                   NaN
# chargeoff_within_12_mths                       NaN                   NaN
# delinq_amnt                                    NaN                   NaN
# mo_sin_old_il_acct                             1.0                   NaN
# mo_sin_old_rev_tl_op                           NaN                   1.0
# mo_sin_rcnt_rev_tl_op                          NaN                   NaN
# mo_sin_rcnt_tl                                 NaN                   NaN
# mort_acc                                       NaN                   NaN
# mths_since_recent_bc                           NaN                   NaN
# mths_since_recent_inq                          NaN                   NaN
# mths_since_recent_revol_delinq                 NaN                   NaN
# num_accts_ever_120_pd                          NaN                   NaN
# num_bc_sats                                    NaN                   NaN
# num_il_tl                                      NaN                   NaN
# num_rev_accts                                  NaN                   NaN
# num_rev_tl_bal_gt_0                            NaN                   NaN
# num_sats                                       NaN                   NaN
# num_tl_120dpd_2m                               NaN                   NaN
# num_tl_30dpd                                   NaN                   NaN
# num_tl_90g_dpd_24m                             NaN                   NaN
# num_tl_op_past_12m                             NaN                   NaN
# pct_tl_nvr_dlq                                 NaN                   NaN
# percent_bc_gt_75                               NaN                   NaN
# pub_rec_bankruptcies                           NaN                   NaN
# tax_liens                                      NaN                   NaN
# tot_hi_cred_lim                                NaN                   NaN
# total_bc_limit                                 NaN                   NaN
# total_il_high_credit_limit                     NaN                   NaN
#
#                                 mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  \
# int_rate                                          NaN             NaN
# installment                                       NaN             NaN
# annual_inc                                        NaN             NaN
# dti                                               NaN             NaN
# delinq_2yrs                                       NaN             NaN
# inq_last_6mths                                    NaN             NaN
# pub_rec                                           NaN             NaN
# total_acc                                         NaN             NaN
# mths_since_last_major_derog                       NaN             NaN
# policy_code                                       NaN             NaN
# tot_coll_amt                                      NaN             NaN
# open_acc_6m                                       NaN             NaN
# open_il_6m                                        NaN             NaN
# open_il_12m                                       NaN             NaN
# open_il_24m                                       NaN             NaN
# mths_since_rcnt_il                                NaN             NaN
# il_util                                           NaN             NaN
# max_bal_bc                                        NaN             NaN
# all_util                                          NaN             NaN
# total_rev_hi_lim                                  NaN             NaN
# inq_fi                                            NaN             NaN
# total_cu_tl                                       NaN             NaN
# inq_last_12m                                      NaN             NaN
# acc_open_past_24mths                              NaN             NaN
# avg_cur_bal                                       NaN             NaN
# chargeoff_within_12_mths                          NaN             NaN
# delinq_amnt                                       NaN             NaN
# mo_sin_old_il_acct                                NaN             NaN
# mo_sin_old_rev_tl_op                              NaN             NaN
# mo_sin_rcnt_rev_tl_op                             1.0             NaN
# mo_sin_rcnt_tl                                    NaN             1.0
# mort_acc                                          NaN             NaN
# mths_since_recent_bc                              NaN             NaN
# mths_since_recent_inq                             NaN             NaN
# mths_since_recent_revol_delinq                    NaN             NaN
# num_accts_ever_120_pd                             NaN             NaN
# num_bc_sats                                       NaN             NaN
# num_il_tl                                         NaN             NaN
# num_rev_accts                                     NaN             NaN
# num_rev_tl_bal_gt_0                               NaN             NaN
# num_sats                                          NaN             NaN
# num_tl_120dpd_2m                                  NaN             NaN
# num_tl_30dpd                                      NaN             NaN
# num_tl_90g_dpd_24m                                NaN             NaN
# num_tl_op_past_12m                                NaN             NaN
# pct_tl_nvr_dlq                                    NaN             NaN
# percent_bc_gt_75                                  NaN             NaN
# pub_rec_bankruptcies                              NaN             NaN
# tax_liens                                         NaN             NaN
# tot_hi_cred_lim                                   NaN             NaN
# total_bc_limit                                    NaN             NaN
# total_il_high_credit_limit                        NaN             NaN
#
#                                 mort_acc  mths_since_recent_bc  \
# int_rate                             NaN                   NaN
# installment                          NaN                   NaN
# annual_inc                           NaN                   NaN
# dti                                  NaN                   NaN
# delinq_2yrs                          NaN                   NaN
# inq_last_6mths                       NaN                   NaN
# pub_rec                              NaN                   NaN
# total_acc                            NaN                   NaN
# mths_since_last_major_derog          NaN                   NaN
# policy_code                          NaN                   NaN
# tot_coll_amt                         NaN                   NaN
# open_acc_6m                          NaN                   NaN
# open_il_6m                           NaN                   NaN
# open_il_12m                          NaN                   NaN
# open_il_24m                          NaN                   NaN
# mths_since_rcnt_il                   NaN                   NaN
# il_util                              NaN                   NaN
# max_bal_bc                           NaN                   NaN
# all_util                             NaN                   NaN
# total_rev_hi_lim                     NaN                   NaN
# inq_fi                               NaN                   NaN
# total_cu_tl                          NaN                   NaN
# inq_last_12m                         NaN                   NaN
# acc_open_past_24mths                 NaN                   NaN
# avg_cur_bal                          NaN                   NaN
# chargeoff_within_12_mths             NaN                   NaN
# delinq_amnt                          NaN                   NaN
# mo_sin_old_il_acct                   NaN                   NaN
# mo_sin_old_rev_tl_op                 NaN                   NaN
# mo_sin_rcnt_rev_tl_op                NaN                   NaN
# mo_sin_rcnt_tl                       NaN                   NaN
# mort_acc                             1.0                   NaN
# mths_since_recent_bc                 NaN                   1.0
# ...
# chargeoff_within_12_mths                       NaN                 NaN
# delinq_amnt                                    NaN                 NaN
# mo_sin_old_il_acct                             NaN                 NaN
# mo_sin_old_rev_tl_op                           NaN                 NaN
# mo_sin_rcnt_rev_tl_op                          NaN                 NaN
# mo_sin_rcnt_tl                                 NaN                 NaN
# mort_acc                                       NaN                 NaN
# mths_since_recent_bc                           NaN                 NaN
# mths_since_recent_inq                          NaN                 NaN
# mths_since_recent_revol_delinq                 NaN                 NaN
# num_accts_ever_120_pd                          NaN                 NaN
# num_bc_sats                                    NaN                 NaN
# num_il_tl                                      NaN                 NaN
# num_rev_accts                                  NaN                 NaN
# num_rev_tl_bal_gt_0                            NaN                 NaN
# num_sats                                       NaN                 NaN
# num_tl_120dpd_2m                               NaN                 NaN
# num_tl_30dpd                                   NaN                 NaN
# num_tl_90g_dpd_24m                             1.0                 NaN
# num_tl_op_past_12m                             NaN                 1.0
# pct_tl_nvr_dlq                                 NaN                 NaN
# percent_bc_gt_75                               NaN                 NaN
# pub_rec_bankruptcies                           NaN                 NaN
# tax_liens                                      NaN                 NaN
# tot_hi_cred_lim                                NaN                 NaN
# total_bc_limit                                 NaN                 NaN
# total_il_high_credit_limit                     NaN                 NaN
#
#                                 pct_tl_nvr_dlq  percent_bc_gt_75  \
# int_rate                                   NaN               NaN
# installment                                NaN               NaN
# annual_inc                                 NaN               NaN
# dti                                        NaN               NaN
# delinq_2yrs                                NaN               NaN
# inq_last_6mths                             NaN               NaN
# pub_rec                                    NaN               NaN
# total_acc                                  NaN               NaN
# mths_since_last_major_derog                NaN               NaN
# policy_code                                NaN               NaN
# tot_coll_amt                               NaN               NaN
# open_acc_6m                                NaN               NaN
# open_il_6m                                 NaN               NaN
# open_il_12m                                NaN               NaN
# open_il_24m                                NaN               NaN
# mths_since_rcnt_il                         NaN               NaN
# il_util                                    NaN               NaN
# max_bal_bc                                 NaN               NaN
# all_util                                   NaN               NaN
# total_rev_hi_lim                           NaN               NaN
# inq_fi                                     NaN               NaN
# total_cu_tl                                NaN               NaN
# inq_last_12m                               NaN               NaN
# acc_open_past_24mths                       NaN               NaN
# avg_cur_bal                                NaN               NaN
# chargeoff_within_12_mths                   NaN               NaN
# delinq_amnt                                NaN               NaN
# mo_sin_old_il_acct                         NaN               NaN
# mo_sin_old_rev_tl_op                       NaN               NaN
# mo_sin_rcnt_rev_tl_op                      NaN               NaN
# mo_sin_rcnt_tl                             NaN               NaN
# mort_acc                                   NaN               NaN
# mths_since_recent_bc                       NaN               NaN
# mths_since_recent_inq                      NaN               NaN
# mths_since_recent_revol_delinq             NaN               NaN
# num_accts_ever_120_pd                      NaN               NaN
# num_bc_sats                                NaN               NaN
# num_il_tl                                  NaN               NaN
# num_rev_accts                              NaN               NaN
# num_rev_tl_bal_gt_0                        NaN               NaN
# num_sats                                   NaN               NaN
# num_tl_120dpd_2m                           NaN               NaN
# num_tl_30dpd                               NaN               NaN
# num_tl_90g_dpd_24m                         NaN               NaN
# num_tl_op_past_12m                         NaN               NaN
# pct_tl_nvr_dlq                             1.0               NaN
# percent_bc_gt_75                           NaN               1.0
# pub_rec_bankruptcies                       NaN               NaN
# tax_liens                                  NaN               NaN
# tot_hi_cred_lim                            NaN               NaN
# total_bc_limit                             NaN               NaN
# total_il_high_credit_limit                 NaN               NaN
#
#                                 pub_rec_bankruptcies  tax_liens  \
# int_rate                                         NaN        NaN
# installment                                      NaN        NaN
# annual_inc                                       NaN        NaN
# dti                                              NaN        NaN
# delinq_2yrs                                      NaN        NaN
# inq_last_6mths                                   NaN        NaN
# pub_rec                                          NaN        NaN
# total_acc                                        NaN        NaN
# mths_since_last_major_derog                      NaN        NaN
# policy_code                                      NaN        NaN
# tot_coll_amt                                     NaN        NaN
# open_acc_6m                                      NaN        NaN
# open_il_6m                                       NaN        NaN
# open_il_12m                                      NaN        NaN
# open_il_24m                                      NaN        NaN
# mths_since_rcnt_il                               NaN        NaN
# il_util                                          NaN        NaN
# max_bal_bc                                       NaN        NaN
# all_util                                         NaN        NaN
# total_rev_hi_lim                                 NaN        NaN
# inq_fi                                           NaN        NaN
# total_cu_tl                                      NaN        NaN
# inq_last_12m                                     NaN        NaN
# acc_open_past_24mths                             NaN        NaN
# avg_cur_bal                                      NaN        NaN
# chargeoff_within_12_mths                         NaN        NaN
# delinq_amnt                                      NaN        NaN
# mo_sin_old_il_acct                               NaN        NaN
# mo_sin_old_rev_tl_op                             NaN        NaN
# mo_sin_rcnt_rev_tl_op                            NaN        NaN
# mo_sin_rcnt_tl                                   NaN        NaN
# mort_acc                                         NaN        NaN
# mths_since_recent_bc                             NaN        NaN
# mths_since_recent_inq                            NaN        NaN
# mths_since_recent_revol_delinq                   NaN        NaN
# num_accts_ever_120_pd                            NaN        NaN
# num_bc_sats                                      NaN        NaN
# num_il_tl                                        NaN        NaN
# num_rev_accts                                    NaN        NaN
# num_rev_tl_bal_gt_0                              NaN        NaN
# num_sats                                         NaN        NaN
# num_tl_120dpd_2m                                 NaN        NaN
# num_tl_30dpd                                     NaN        NaN
# num_tl_90g_dpd_24m                               NaN        NaN
# num_tl_op_past_12m                               NaN        NaN
# pct_tl_nvr_dlq                                   NaN        NaN
# percent_bc_gt_75                                 NaN        NaN
# pub_rec_bankruptcies                             1.0        NaN
# tax_liens                                        NaN        1.0
# tot_hi_cred_lim                                  NaN        NaN
# total_bc_limit                                   NaN        NaN
# total_il_high_credit_limit                       NaN        NaN
#
#                                 tot_hi_cred_lim  total_bc_limit  \
# int_rate                                    NaN             NaN
# installment                                 NaN             NaN
# annual_inc                                  NaN             NaN
# dti                                         NaN             NaN
# delinq_2yrs                                 NaN             NaN
# inq_last_6mths                              NaN             NaN
# pub_rec                                     NaN             NaN
# total_acc                                   NaN             NaN
# mths_since_last_major_derog                 NaN             NaN
# policy_code                                 NaN             NaN
# tot_coll_amt                                NaN             NaN
# open_acc_6m                                 NaN             NaN
# open_il_6m                                  NaN             NaN
# open_il_12m                                 NaN             NaN
# open_il_24m                                 NaN             NaN
# mths_since_rcnt_il                          NaN             NaN
# il_util                                     NaN             NaN
# max_bal_bc                                  NaN             NaN
# all_util                                    NaN             NaN
# total_rev_hi_lim                            NaN             NaN
# inq_fi                                      NaN             NaN
# total_cu_tl                                 NaN             NaN
# inq_last_12m                                NaN             NaN
# acc_open_past_24mths                        NaN             NaN
# avg_cur_bal                                 NaN             NaN
# chargeoff_within_12_mths                    NaN             NaN
# delinq_amnt                                 NaN             NaN
# mo_sin_old_il_acct                          NaN             NaN
# mo_sin_old_rev_tl_op                        NaN             NaN
# mo_sin_rcnt_rev_tl_op                       NaN             NaN
# mo_sin_rcnt_tl                              NaN             NaN
# mort_acc                                    NaN             NaN
# mths_since_recent_bc                        NaN             NaN
# mths_since_recent_inq                       NaN             NaN
# mths_since_recent_revol_delinq              NaN             NaN
# num_accts_ever_120_pd                       NaN             NaN
# num_bc_sats                                 NaN             NaN
# num_il_tl                                   NaN             NaN
# num_rev_accts                               NaN             NaN
# num_rev_tl_bal_gt_0                         NaN             NaN
# num_sats                                    NaN             NaN
# num_tl_120dpd_2m                            NaN             NaN
# num_tl_30dpd                                NaN             NaN
# num_tl_90g_dpd_24m                          NaN             NaN
# num_tl_op_past_12m                          NaN             NaN
# pct_tl_nvr_dlq                              NaN             NaN
# percent_bc_gt_75                            NaN             NaN
# pub_rec_bankruptcies                        NaN             NaN
# tax_liens                                   NaN             NaN
# tot_hi_cred_lim                             1.0             NaN
# total_bc_limit                              NaN             1.0
# total_il_high_credit_limit                  NaN             NaN
#
#                                 total_il_high_credit_limit
# int_rate                                               NaN
# installment                                            NaN
# annual_inc                                             NaN
# dti                                                    NaN
# delinq_2yrs                                            NaN
# inq_last_6mths                                         NaN
# pub_rec                                                NaN
# total_acc                                              NaN
# mths_since_last_major_derog                            NaN
# policy_code                                            NaN
# tot_coll_amt                                           NaN
# open_acc_6m                                            NaN
# open_il_6m                                             NaN
# open_il_12m                                            NaN
# open_il_24m                                            NaN
# mths_since_rcnt_il                                     NaN
# il_util                                                NaN
# max_bal_bc                                             NaN
# all_util                                               NaN
# total_rev_hi_lim                                       NaN
# inq_fi                                                 NaN
# total_cu_tl                                            NaN
# inq_last_12m                                           NaN
# acc_open_past_24mths                                   NaN
# avg_cur_bal                                            NaN
# chargeoff_within_12_mths                               NaN
# delinq_amnt                                            NaN
# mo_sin_old_il_acct                                     NaN
# mo_sin_old_rev_tl_op                                   NaN
# mo_sin_rcnt_rev_tl_op                                  NaN
# mo_sin_rcnt_tl                                         NaN
# mort_acc                                               NaN
# mths_since_recent_bc                                   NaN
# mths_since_recent_inq                                  NaN
# mths_since_recent_revol_delinq                         NaN
# num_accts_ever_120_pd                                  NaN
# num_bc_sats                                            NaN
# num_il_tl                                              NaN
# num_rev_accts                                          NaN
# num_rev_tl_bal_gt_0                                    NaN
# num_sats                                               NaN
# num_tl_120dpd_2m                                       NaN
# num_tl_30dpd                                           NaN
# num_tl_90g_dpd_24m                                     NaN
# num_tl_op_past_12m                                     NaN
# pct_tl_nvr_dlq                                         NaN
# percent_bc_gt_75                                       NaN
# pub_rec_bankruptcies                                   NaN
# tax_liens                                              NaN
# tot_hi_cred_lim                                        NaN
# total_bc_limit                                         NaN
# total_il_high_credit_limit                             1.0

# %%
df1['const'] = 1
df1.head()
# Out:
#          term  int_rate  installment sub_grade home_ownership  annual_inc  \
# 0   60 months    0.0975       337.99        B3            OWN    120000.0
# 1   36 months    0.0739       186.34        A4       MORTGAGE     72000.0
# 2   36 months    0.1825       204.07        D3       MORTGAGE     53328.0
# 3   36 months    0.1075       195.73        B4           RENT     35000.0
# 4   36 months    0.0839       315.17        B1           RENT     48000.0
#
#   pymnt_plan    dti  delinq_2yrs  inq_last_6mths  pub_rec  total_acc  \
# 0          n  13.68            1             0.0        0         38
# 1          n  10.68            0             0.0        0         18
# 2          n  10.51            0             0.0        0         14
# 3          n  20.58            0             0.0        0          8
# 4          n  29.58            0             0.0        1         17
#
#    mths_since_last_major_derog  policy_code application_type  tot_coll_amt  \
# 0                         53.0            1       INDIVIDUAL           350
# 1                          NaN            1       INDIVIDUAL           157
# 2                          NaN            1       INDIVIDUAL          2124
# 3                          NaN            1       INDIVIDUAL             0
# 4                          NaN            1       INDIVIDUAL           734
#
#    open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  \
# 0          2.0         3.0          2.0          2.0                 2.0
# 1          0.0         5.0          1.0          1.0                 7.0
# 2          3.0         1.0          1.0          3.0                 3.0
# 3          1.0         1.0          0.0          1.0                16.0
# 4          0.0         3.0          0.0          1.0                23.0
#
#    il_util  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0     68.0      4244.0      46.0             54900     5.0          1.0
# 1     87.0      3147.0      55.0             23000     0.0          3.0
# 2     98.0       361.0      65.0              6600     0.0          1.0
# 3     81.0       872.0      80.0              4900     1.0          0.0
# 4     66.0      2987.0      63.0             13600     2.0          4.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  chargeoff_within_12_mths  \
# 0          11.0                    11         4542                         0
# 1           2.0                     4         2052                         0
# 2           0.0                     8        22331                         0
# 3           0.0                     6         3838                         0
# 4           0.0                     3         3255                         0
#
#    delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 0            0               157.0                   256
# 1            0                89.0                    84
# 2            0               121.0                   132
# 3            0                16.0                   130
# 4            0                48.0                    41
#
#    mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                     12               2         1                  14.0
# 1                     14               7         0                  14.0
# 2                      2               2         1                   2.0
# 3                      3               3         0                  10.0
# 4                      7               7         0                  31.0
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    2.0                            20.0
# 1                    9.0                             NaN
# 2                   14.0                            81.0
# 3                   16.0                             NaN
# 4                   18.0                             NaN
#
#    num_accts_ever_120_pd  num_bc_sats  num_il_tl  num_rev_accts  \
# 0                      1            6          8             28
# 1                      0            2          8             10
# 2                      0            3          7              6
# 3                      0            3          1              7
# 4                      0            2          4             13
#
#    num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  num_tl_30dpd  \
# 0                   13        25               0.0             0
# 1                    4        12               0.0             0
# 2                    4         7               0.0             0
# 3                    6         7               0.0             0
# 4                    7        13               0.0             0
#
#    num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                   0                   5            94.6              16.7
# 1                   0                   1           100.0               0.0
# 2                   0                   4            84.6               0.0
# 3                   0                   3           100.0             100.0
# 4                   0                   1           100.0               0.0
#
#    pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bc_limit  \
# 0                     0          0           160515           25000
# 1                     0          0            45139            9400
# 2                     0          0           200449            2600
# 3                     0          0            33626            2100
# 4                     0          0            61807            5800
#
#    total_il_high_credit_limit  const
# 0                       38196      1
# 1                       22139      1
# 2                        7704      1
# 3                       28726      1
# 4                       48207      1

# %%
df2 = df1.dropna(axis=0)

# %%
df2.shape
# Out:
# (61490, 58)

# %%
df2cat = df2[['term', 'sub_grade', 'home_ownership', 'pymnt_plan', 'application_type', 'policy_code']]
df2y = df2[['int_rate']]
df2X = df2.drop(['term', 'sub_grade', 'home_ownership', 'pymnt_plan', 'application_type', 'policy_code', 'int_rate'], axis=1)

# %%
rs1 = sm.OLS(df2y, df2X).fit()
print(rs1.summary())

# %%
# Out:
# array([-0.00165541, -0.00143141, -0.00134712, -0.0015477 , -0.0015612 ,
#        -0.00181553, -0.00157587, -0.00173735, -0.00171976, -0.00173864])

# %%
rs2 = sm.OLS.from_formula('int_rate ~ installment + annual_inc + dti + delinq_2yrs + inq_last_6mths + total_acc + mths_since_last_major_derog + open_acc_6m + open_il_12m + open_il_24m + mths_since_rcnt_il + il_util + max_bal_bc + all_util + total_rev_hi_lim + inq_fi + total_cu_tl + inq_last_12m + acc_open_past_24mths + delinq_amnt + mo_sin_old_il_acct + mo_sin_old_rev_tl_op + mort_acc + mths_since_recent_bc + mths_since_recent_inq + mths_since_recent_revol_delinq + num_accts_ever_120_pd + num_bc_sats + num_sats + num_tl_30dpd + num_tl_90g_dpd_24m + num_tl_op_past_12m + percent_bc_gt_75 + pub_rec_bankruptcies + tot_hi_cred_lim + total_bc_limit + total_il_high_credit_limit', df2).fit()
print(rs2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               int_rate   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     743.3
# Date:                Wed, 12 Jul 2017   Prob (F-statistic):               0.00
# Time:                        02:25:17   Log-Likelihood:             1.1069e+05
# No. Observations:               61490   AIC:                        -2.213e+05
# Df Residuals:                   61452   BIC:                        -2.210e+05
# Df Model:                          37
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.0857      0.001     68.710      0.000       0.083       0.088
# installment                     6.274e-05   6.82e-07     91.952      0.000    6.14e-05    6.41e-05
# annual_inc                     -2.893e-08    2.9e-09     -9.992      0.000   -3.46e-08   -2.33e-08
# dti                                0.0012   2.48e-05     49.475      0.000       0.001       0.001
# delinq_2yrs                        0.0020      0.000     10.481      0.000       0.002       0.002
# inq_last_6mths                     0.0056      0.000     24.249      0.000       0.005       0.006
# total_acc                         -0.0005    2.3e-05    -19.821      0.000      -0.001      -0.000
# mths_since_last_major_derog    -4.742e-05   9.79e-06     -4.844      0.000   -6.66e-05   -2.82e-05
# open_acc_6m                        0.0005      0.000      2.451      0.014    9.34e-05       0.001
# open_il_12m                        0.0039      0.000     13.404      0.000       0.003       0.004
# open_il_24m                       -0.0008      0.000     -4.065      0.000      -0.001      -0.000
# mths_since_rcnt_il              4.095e-05   1.08e-05      3.798      0.000    1.98e-05    6.21e-05
# il_util                         7.409e-05   1.25e-05      5.943      0.000    4.97e-05    9.85e-05
# max_bal_bc                     -2.776e-07    6.2e-08     -4.477      0.000   -3.99e-07   -1.56e-07
# all_util                           0.0003   1.66e-05     16.570      0.000       0.000       0.000
# total_rev_hi_lim               -5.353e-08   9.03e-09     -5.931      0.000   -7.12e-08   -3.58e-08
# inq_fi                             0.0003      0.000      2.971      0.003       0.000       0.001
# total_cu_tl                       -0.0005   6.01e-05     -7.703      0.000      -0.001      -0.000
# inq_last_12m                       0.0005   8.58e-05      6.025      0.000       0.000       0.001
# acc_open_past_24mths               0.0019   9.76e-05     19.909      0.000       0.002       0.002
# delinq_amnt                     4.318e-07   9.98e-08      4.328      0.000    2.36e-07    6.27e-07
# mo_sin_old_il_acct             -3.076e-05   3.49e-06     -8.818      0.000   -3.76e-05   -2.39e-05
# mo_sin_old_rev_tl_op           -4.495e-05    1.9e-06    -23.599      0.000   -4.87e-05   -4.12e-05
# mort_acc                          -0.0008      0.000     -7.116      0.000      -0.001      -0.001
# mths_since_recent_bc            -6.41e-05   5.46e-06    -11.733      0.000   -7.48e-05   -5.34e-05
# mths_since_recent_inq             -0.0003   3.62e-05     -9.431      0.000      -0.000      -0.000
# mths_since_recent_revol_delinq -5.621e-05   9.44e-06     -5.957      0.000   -7.47e-05   -3.77e-05
# num_accts_ever_120_pd              0.0002   8.01e-05      2.734      0.006     6.2e-05       0.000
# num_bc_sats                        0.0006      0.000      5.818      0.000       0.000       0.001
# num_sats                          -0.0005   5.26e-05     -9.538      0.000      -0.001      -0.000
# num_tl_30dpd                       0.0151      0.002      7.046      0.000       0.011       0.019
# num_tl_90g_dpd_24m                -0.0007      0.000     -2.500      0.012      -0.001      -0.000
# num_tl_op_past_12m                 0.0019      0.000     11.276      0.000       0.002       0.002
# percent_bc_gt_75                   0.0002   5.46e-06     27.904      0.000       0.000       0.000
# pub_rec_bankruptcies               0.0032      0.000      6.945      0.000       0.002       0.004
# tot_hi_cred_lim                -8.636e-09   1.26e-09     -6.833      0.000   -1.11e-08   -6.16e-09
# total_bc_limit                 -3.741e-07   2.28e-08    -16.418      0.000   -4.19e-07   -3.29e-07
# total_il_high_credit_limit      -6.33e-08   4.83e-09    -13.119      0.000   -7.28e-08   -5.38e-08
# ==============================================================================
# Omnibus:                     6137.968   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8413.064
# Skew:                           0.814   Prob(JB):                         0.00
# Kurtosis:                       3.798   Cond. No.                     3.63e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.63e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
rs3 = sm.OLS.from_formula('int_rate ~ sub_grade + 0', df2).fit()
print(rs3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               int_rate   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 9.244e+04
# Date:                Wed, 12 Jul 2017   Prob (F-statistic):               0.00
# Time:                        02:00:28   Log-Likelihood:             2.2088e+05
# No. Observations:               61490   AIC:                        -4.417e+05
# Df Residuals:                   61455   BIC:                        -4.414e+05
# Df Model:                          34
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# sub_grade[A1]     0.0532      0.000    273.821      0.000       0.053       0.054
# sub_grade[A2]     0.0668      0.000    288.293      0.000       0.066       0.067
# sub_grade[A3]     0.0717      0.000    330.005      0.000       0.071       0.072
# sub_grade[A4]     0.0751      0.000    443.274      0.000       0.075       0.075
# sub_grade[A5]     0.0808      0.000    513.068      0.000       0.081       0.081
# sub_grade[B1]     0.0854      0.000    739.238      0.000       0.085       0.086
# sub_grade[B2]     0.0949      0.000    831.739      0.000       0.095       0.095
# sub_grade[B3]     0.1026      0.000    927.753      0.000       0.102       0.103
# sub_grade[B4]     0.1096      0.000   1071.471      0.000       0.109       0.110
# sub_grade[B5]     0.1148    9.6e-05   1195.709      0.000       0.115       0.115
# sub_grade[C1]     0.1243   9.55e-05   1301.434      0.000       0.124       0.124
# sub_grade[C2]     0.1325      0.000   1273.995      0.000       0.132       0.133
# sub_grade[C3]     0.1382      0.000   1293.704      0.000       0.138       0.138
# sub_grade[C4]     0.1454      0.000   1377.855      0.000       0.145       0.146
# sub_grade[C5]     0.1552      0.000   1400.932      0.000       0.155       0.155
# sub_grade[D1]     0.1661      0.000   1203.701      0.000       0.166       0.166
# sub_grade[D2]     0.1765      0.000   1264.842      0.000       0.176       0.177
# sub_grade[D3]     0.1860      0.000   1157.230      0.000       0.186       0.186
# sub_grade[D4]     0.1945      0.000   1159.655      0.000       0.194       0.195
# sub_grade[D5]     0.2050      0.000   1129.268      0.000       0.205       0.205
# sub_grade[E1]     0.2128      0.000   1099.385      0.000       0.212       0.213
# sub_grade[E2]     0.2191      0.000    929.261      0.000       0.219       0.220
# sub_grade[E3]     0.2282      0.000   1002.394      0.000       0.228       0.229
# sub_grade[E4]     0.2346      0.000    914.364      0.000       0.234       0.235
# sub_grade[E5]     0.2394      0.000    867.161      0.000       0.239       0.240
# sub_grade[F1]     0.2466      0.000    818.201      0.000       0.246       0.247
# sub_grade[F2]     0.2576      0.000    720.905      0.000       0.257       0.258
# sub_grade[F3]     0.2618      0.000    624.836      0.000       0.261       0.263
# sub_grade[F4]     0.2672      0.000    613.206      0.000       0.266       0.268
# sub_grade[F5]     0.2754      0.000    563.566      0.000       0.274       0.276
# sub_grade[G1]     0.2806      0.001    433.392      0.000       0.279       0.282
# sub_grade[G2]     0.2878      0.001    448.758      0.000       0.287       0.289
# sub_grade[G3]     0.2887      0.001    399.315      0.000       0.287       0.290
# sub_grade[G4]     0.2931      0.001    337.707      0.000       0.291       0.295
# sub_grade[G5]     0.2997      0.001    287.860      0.000       0.298       0.302
# ==============================================================================
# Omnibus:                    43800.490   Durbin-Watson:                   1.237
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15220249.222
# Skew:                          -2.301   Prob(JB):                         0.00
# Kurtosis:                      79.938   Cond. No.                         10.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sm.stats.anova_lm(rs2)
# Out:
# C:\Users\Ryoo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\Ryoo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\Ryoo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#                                      df     sum_sq   mean_sq            F  \
# installment                         1.0   8.355632  8.355632  5220.897609
# annual_inc                          1.0   3.260028  3.260028  2036.981824
# dti                                 1.0   4.196613  4.196613  2622.193491
# delinq_2yrs                         1.0   0.157864  0.157864    98.639316
# inq_last_6mths                      1.0   5.190464  5.190464  3243.187606
# total_acc                           1.0   1.803801  1.803801  1127.079106
# mths_since_last_major_derog         1.0   0.044895  0.044895    28.051968
# open_acc_6m                         1.0   2.612958  2.612958  1632.669567
# open_il_12m                         1.0   3.655078  3.655078  2283.823092
# open_il_24m                         1.0   0.296135  0.296135   185.036018
# mths_since_rcnt_il                  1.0   0.003891  0.003891     2.431410
# il_util                             1.0   1.719804  1.719804  1074.595093
# max_bal_bc                          1.0   1.110149  1.110149   693.660815
# all_util                            1.0   2.437380  2.437380  1522.961979
# total_rev_hi_lim                    1.0   0.660267  0.660267   412.558296
# inq_fi                              1.0   0.192604  0.192604   120.345998
# total_cu_tl                         1.0   0.085810  0.085810    53.617466
# inq_last_12m                        1.0   0.461686  0.461686   288.477633
# acc_open_past_24mths                1.0   2.937318  2.937318  1835.341027
# delinq_amnt                         1.0   0.013037  0.013037     8.146038
# mo_sin_old_il_acct                  1.0   0.179590  0.179590   112.214507
# mo_sin_old_rev_tl_op                1.0   0.789954  0.789954   493.591200
# mort_acc                            1.0   0.132340  0.132340    82.690643
# mths_since_recent_bc                1.0   0.155009  0.155009    96.854904
# mths_since_recent_inq               1.0   0.125323  0.125323    78.306182
# mths_since_recent_revol_delinq      1.0   0.070681  0.070681    44.164148
# num_accts_ever_120_pd               1.0   0.012319  0.012319     7.697597
# num_bc_sats                         1.0   0.132039  0.132039    82.502896
# num_sats                            1.0   0.213775  0.213775   133.573996
# num_tl_30dpd                        1.0   0.059943  0.059943    37.454540
# num_tl_90g_dpd_24m                  1.0   0.011381  0.011381     7.110953
# num_tl_op_past_12m                  1.0   0.188001  0.188001   117.469506
# percent_bc_gt_75                    1.0   1.619656  1.619656  1012.018713
# pub_rec_bankruptcies                1.0   0.106740  0.106740    66.694823
# tot_hi_cred_lim                     1.0   0.234441  0.234441   146.487192
# total_bc_limit                      1.0   0.515367  0.515367   322.019863
# total_il_high_credit_limit          1.0   0.275425  0.275425   172.095475
# Residual                        61452.0  98.349049  0.001600          NaN
#
#                                        PR(>F)
# installment                      0.000000e+00
# annual_inc                       0.000000e+00
# dti                              0.000000e+00
# delinq_2yrs                      3.154147e-23
# inq_last_6mths                   0.000000e+00
# total_acc                       7.156787e-245
# mths_since_last_major_derog      1.185062e-07
# open_acc_6m                      0.000000e+00
# open_il_12m                      0.000000e+00
# open_il_24m                      4.435651e-42
# mths_since_rcnt_il               1.189310e-01
# il_util                         1.150973e-233
# max_bal_bc                      5.016803e-152
# all_util                         0.000000e+00
# total_rev_hi_lim                 2.032755e-91
# inq_fi                           5.641113e-28
# total_cu_tl                      2.465547e-13
# inq_last_12m                     1.499195e-64
# acc_open_past_24mths             0.000000e+00
# delinq_amnt                      4.316977e-03
# mo_sin_old_il_acct               3.378101e-26
# mo_sin_old_rev_tl_op            6.343198e-109
# mort_acc                         9.872460e-20
# mths_since_recent_bc             7.755814e-23
# mths_since_recent_inq            9.052966e-19
# mths_since_recent_revol_delinq   3.044742e-11
# num_accts_ever_120_pd            5.531108e-03
# num_bc_sats                      1.085478e-19
# num_sats                         7.288017e-31
# num_tl_30dpd                     9.413229e-10
# num_tl_90g_dpd_24m               7.663445e-03
# num_tl_op_past_12m               2.398496e-27
# percent_bc_gt_75                2.724554e-220
# pub_rec_bankruptcies             3.229243e-16
# tot_hi_cred_lim                  1.109694e-33
# total_bc_limit                   8.028662e-72
# total_il_high_credit_limit       2.913031e-39
# Residual                                  NaN

# %%
df2['lograte'] = df2.int_rate.map(np.log)
# Out:
# C:\Users\Ryoo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rs2 = sm.OLS.from_formula('lograte ~ installment + annual_inc + dti + delinq_2yrs + inq_last_6mths + total_acc + mths_since_last_major_derog + open_acc_6m + open_il_12m + open_il_24m + il_util + max_bal_bc + all_util + total_rev_hi_lim + inq_fi + total_cu_tl + inq_last_12m + acc_open_past_24mths + delinq_amnt + mo_sin_old_il_acct + mo_sin_old_rev_tl_op + mort_acc + mths_since_recent_bc + mths_since_recent_inq + mths_since_recent_revol_delinq + num_accts_ever_120_pd + num_bc_sats + num_sats + num_tl_30dpd + num_tl_90g_dpd_24m + num_tl_op_past_12m + percent_bc_gt_75 + pub_rec_bankruptcies + tot_hi_cred_lim + total_bc_limit + total_il_high_credit_limit', df2).fit()
print(rs2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lograte   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     785.9
# Date:                Wed, 12 Jul 2017   Prob (F-statistic):               0.00
# Time:                        02:38:49   Log-Likelihood:                -10582.
# No. Observations:               61490   AIC:                         2.124e+04
# Df Residuals:                   61453   BIC:                         2.157e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -2.3183      0.008   -274.141      0.000      -2.335      -2.302
# I(installment ** 2)             3.304e-07   4.08e-09     81.024      0.000    3.22e-07    3.38e-07
# annual_inc                     -1.874e-07   2.08e-08     -9.024      0.000   -2.28e-07   -1.47e-07
# dti                                0.0088      0.000     50.027      0.000       0.008       0.009
# delinq_2yrs                        0.0168      0.001     12.306      0.000       0.014       0.019
# inq_last_6mths                     0.0397      0.002     24.149      0.000       0.037       0.043
# total_acc                         -0.0034      0.000    -20.573      0.000      -0.004      -0.003
# mths_since_last_major_derog       -0.0004   7.03e-05     -5.550      0.000      -0.001      -0.000
# open_acc_6m                        0.0033      0.001      2.411      0.016       0.001       0.006
# open_il_12m                        0.0277      0.002     13.501      0.000       0.024       0.032
# open_il_24m                       -0.0088      0.001     -6.667      0.000      -0.011      -0.006
# il_util                            0.0004   8.84e-05      4.020      0.000       0.000       0.001
# max_bal_bc                      8.978e-08   4.45e-07      0.202      0.840   -7.82e-07    9.62e-07
# all_util                           0.0023      0.000     19.555      0.000       0.002       0.003
# total_rev_hi_lim               -4.147e-07   6.49e-08     -6.394      0.000   -5.42e-07   -2.88e-07
# inq_fi                             0.0031      0.001      3.744      0.000       0.001       0.005
# total_cu_tl                       -0.0030      0.000     -6.934      0.000      -0.004      -0.002
# inq_last_12m                       0.0035      0.001      5.619      0.000       0.002       0.005
# acc_open_past_24mths               0.0156      0.001     22.283      0.000       0.014       0.017
# delinq_amnt                     3.437e-06   7.17e-07      4.794      0.000    2.03e-06    4.84e-06
# mo_sin_old_il_acct                -0.0002    2.5e-05     -8.679      0.000      -0.000      -0.000
# mo_sin_old_rev_tl_op              -0.0003   1.37e-05    -25.415      0.000      -0.000      -0.000
# mort_acc                          -0.0053      0.001     -6.996      0.000      -0.007      -0.004
# mths_since_recent_bc              -0.0005   3.93e-05    -12.314      0.000      -0.001      -0.000
# mths_since_recent_inq             -0.0029      0.000    -11.340      0.000      -0.003      -0.002
# mths_since_recent_revol_delinq    -0.0004   6.78e-05     -6.183      0.000      -0.001      -0.000
# num_accts_ever_120_pd              0.0020      0.001      3.505      0.000       0.001       0.003
# num_bc_sats                        0.0079      0.001     10.228      0.000       0.006       0.009
# num_sats                          -0.0040      0.000    -10.522      0.000      -0.005      -0.003
# num_tl_30dpd                       0.1200      0.015      7.809      0.000       0.090       0.150
# num_tl_90g_dpd_24m                -0.0067      0.002     -3.245      0.001      -0.011      -0.003
# num_tl_op_past_12m                 0.0134      0.001     10.918      0.000       0.011       0.016
# percent_bc_gt_75                   0.0013   3.92e-05     31.921      0.000       0.001       0.001
# pub_rec_bankruptcies               0.0252      0.003      7.655      0.000       0.019       0.032
# tot_hi_cred_lim                -7.419e-08   9.08e-09     -8.170      0.000    -9.2e-08   -5.64e-08
# total_bc_limit                 -3.361e-06   1.64e-07    -20.528      0.000   -3.68e-06   -3.04e-06
# total_il_high_credit_limit     -4.165e-07   3.47e-08    -12.013      0.000   -4.84e-07   -3.49e-07
# ==============================================================================
# Omnibus:                      167.888   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              168.811
# Skew:                           0.126   Prob(JB):                     2.20e-37
# Kurtosis:                       2.948   Cond. No.                     5.85e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.85e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
a = 'installment + annual_inc + dti + delinq_2yrs + inq_last_6mths + total_acc + mths_since_last_major_derog + open_acc_6m + open_il_12m + open_il_24m + mths_since_rcnt_il + il_util + max_bal_bc + all_util + total_rev_hi_lim + inq_fi + total_cu_tl + inq_last_12m + acc_open_past_24mths + delinq_amnt + mo_sin_old_il_acct + mo_sin_old_rev_tl_op + mort_acc + mths_since_recent_bc + mths_since_recent_inq + mths_since_recent_revol_delinq + num_accts_ever_120_pd + num_bc_sats + num_sats + num_tl_30dpd + num_tl_90g_dpd_24m + num_tl_op_past_12m + percent_bc_gt_75 + pub_rec_bankruptcies + tot_hi_cred_lim + total_bc_limit + total_il_high_credit_limit'.split(' + ')
df3X = df2[a]
df3y = df2.int_rate
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
cross_val_score(LinearRegression(), df3X, df3y, scoring="neg_mean_squared_error", cv=10)
