# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
# Out:
# C:\Users\Ryoo\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df0 = pd.read_csv('lcdf3.csv')

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
df0.head()
# Out:
#    loan_amnt        term  int_rate  installment sub_grade home_ownership  \
# 0      16000   60 months    0.0975       337.99        B3            OWN
# 1       6000   36 months    0.0739       186.34        A4       MORTGAGE
# 2       5625   36 months    0.1825       204.07        D3       MORTGAGE
# 3       6000   36 months    0.1075       195.73        B4           RENT
# 4      10000   36 months    0.0839       315.17        B1           RENT
#
#    annual_inc pymnt_plan    dti  delinq_2yrs  inq_last_6mths  \
# 0    120000.0          n  13.68            1             0.0
# 1     72000.0          n  10.68            0             0.0
# 2     53328.0          n  10.51            0             0.0
# 3     35000.0          n  20.58            0             0.0
# 4     48000.0          n  29.58            0             0.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    20.0                     NaN        25        0
# 1                     NaN                     NaN        12        0
# 2                    67.0                     NaN         7        0
# 3                     NaN                     NaN         7        0
# 4                     NaN                    25.0        13        1
#
#    revol_bal  revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  \
# 0      16763       0.305         38   13160.31       13160.31  4376.540000
# 1       5426       0.236         18       0.00           0.00  6369.416519
# 2       1773       0.269         14    3935.46        3935.46  2655.450000
# 3       3691       0.753          8    4051.72        4051.72  2537.320000
# 4       7089       0.521         17    6674.47        6674.47  4087.890000
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          4376.54          2839.69        1536.85                 0.0
# 1          6369.42          6000.00         369.42                 0.0
# 2          2655.45          1689.54         965.91                 0.0
# 3          2537.32          1948.28         589.04                 0.0
# 4          4087.89          3325.53         762.36                 0.0
#
#    recoveries  collection_recovery_fee  last_pymnt_amnt  \
# 0         0.0                      0.0           337.99
# 1         0.0                      0.0          4510.95
# 2         0.0                      0.0           204.07
# 3         0.0                      0.0           195.73
# 4         0.0                      0.0           315.17
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                           1                         53.0            1
# 1                           0                          NaN            1
# 2                           0                          NaN            1
# 3                           0                          NaN            1
# 4                           0                          NaN            1
#
#   application_type  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  \
# 0       INDIVIDUAL               0           350       109019          2.0
# 1       INDIVIDUAL               0           157        24618          0.0
# 2       INDIVIDUAL               0          2124       156318          3.0
# 3       INDIVIDUAL               0             0        26867          1.0
# 4       INDIVIDUAL               0           734        39061          0.0
#
#    open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  \
# 0         3.0          2.0          2.0                 2.0       25781.0
# 1         5.0          1.0          1.0                 7.0       19192.0
# 2         1.0          1.0          3.0                 3.0        7560.0
# 3         1.0          0.0          1.0                16.0       23176.0
# 4         3.0          0.0          1.0                23.0       31972.0
#
#    il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 0     68.0          1.0          7.0      4244.0      46.0             54900
# 1     87.0          0.0          3.0      3147.0      55.0             23000
# 2     98.0          3.0          5.0       361.0      65.0              6600
# 3     81.0          3.0          5.0       872.0      80.0              4900
# 4     66.0          1.0          2.0      2987.0      63.0             13600
#
#    inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0     5.0          1.0          11.0                    11         4542
# 1     0.0          3.0           2.0                     4         2052
# 2     0.0          1.0           0.0                     8        22331
# 3     1.0          0.0           0.0                     6         3838
# 4     2.0          4.0           0.0                     3         3255
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0         12857.0     48.6                         0            0
# 1          4158.0     55.8                         0            0
# 2          1809.0     30.4                         0            0
# 3           334.0     84.1                         0            0
# 4          2327.0     59.9                         0            0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0               157.0                   256                     12
# 1                89.0                    84                     14
# 2               121.0                   132                      2
# 3                16.0                   130                      3
# 4                48.0                    41                      7
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0               2         1                  14.0                       NaN
# 1               7         0                  14.0                       NaN
# 2               2         1                   2.0                      81.0
# 3               3         0                  10.0                       NaN
# 4               7         0                  31.0                       NaN
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    2.0                            20.0
# 1                    9.0                             NaN
# 2                   14.0                            81.0
# 3                   16.0                             NaN
# 4                   18.0                             NaN
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                      1               5               13            6
# 1                      0               2                4            2
# 2                      0               3                4            3
# 3                      0               3                6            3
# 4                      0               2                7            2
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0         10          8             19             28                   13
# 1          4          8              7             10                    4
# 2          4          7              5              6                    4
# 3          3          1              6              7                    6
# 4          2          4             10             13                    7
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0        25               0.0             0                   0
# 1        12               0.0             0                   0
# 2         7               0.0             0                   0
# 3         7               0.0             0                   0
# 4        13               0.0             0                   0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                   5            94.6              16.7                     0
# 1                   1           100.0               0.0                     0
# 2                   4            84.6               0.0                     0
# 3                   3           100.0             100.0                     0
# 4                   1           100.0               0.0                     0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          0           160515              42544           25000
# 1          0            45139              24618            9400
# 2          0           200449               9333            2600
# 3          0            33626              26867            2100
# 4          0            61807              39061            5800
#
#    total_il_high_credit_limit
# 0                       38196
# 1                       22139
# 2                        7704
# 3                       28726
# 4                       48207

# %%
df0corr = df0.corr()
df0corr.shape

# %%
df0corr[(df0corr >= 0.8) | (df0corr <= -0.8)].fillna('')
# Out:
#                                loan_amnt int_rate installment annual_inc dti  \
# loan_amnt                              1             0.950004
# int_rate                                        1
# installment                     0.950004                    1
# annual_inc                                                             1
# dti                                                                        1
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                delinq_2yrs inq_last_6mths  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs                              1
# inq_last_6mths                                          1
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                mths_since_last_delinq mths_since_last_record  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq                              1
# mths_since_last_record                                                     1
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq               0.859438
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                 open_acc pub_rec revol_bal revol_util  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc                               1
# pub_rec                                        1
# revol_bal                                                1
# revol_util                                                          1
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim                                  0.833575
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util                                                      0.858375
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl                   0.833676
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats                        0.998651
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                total_acc out_prncp out_prncp_inv total_pymnt  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc                              1
# out_prncp                                        1      0.999995
# out_prncp_inv                             0.999995             1
# total_pymnt                                                                1
# total_pymnt_inv                                                     0.999996
# total_rec_prncp                                                     0.976723
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt                                                     0.814659
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                total_pymnt_inv total_rec_prncp total_rec_int  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt                           0.999996        0.976723
# total_pymnt_inv                              1        0.976716
# total_rec_prncp                       0.976716               1
# total_rec_int                                                              1
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt                        0.81466         0.86936
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                total_rec_late_fee recoveries  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee                              1
# recoveries                                                 1
# collection_recovery_fee                             0.933082
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                collection_recovery_fee last_pymnt_amnt  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt                                                   0.814659
# total_pymnt_inv                                                0.81466
# total_rec_prncp                                                0.86936
# total_rec_int
# total_rec_late_fee
# recoveries                                    0.933082
# collection_recovery_fee                              1
# last_pymnt_amnt                                                      1
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# ...
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util                                0.845079
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75                              1
# pub_rec_bankruptcies                                               1
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal                                     0.971236
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il                                                      0.893174
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens                              1
# tot_hi_cred_lim                                        1
# total_bal_ex_mort                                                        1
# total_bc_limit
# total_il_high_credit_limit                                        0.879395
#
#                                total_bc_limit total_il_high_credit_limit
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_amnt
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il                                                    0.956908
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy                       0.823009
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort                                               0.879395
# total_bc_limit                              1
# total_il_high_credit_limit                                             1

# %%
df0.drop(['out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'collections_12_mths_ex_med'], axis=1, inplace=True)

# %%
df0corr = df0.corr()

# %%
df0corr[(df0corr >= 0.8) | (df0corr <= -0.8)].fillna('')
# Out:
#                                loan_amnt int_rate installment annual_inc dti  \
# loan_amnt                              1             0.950004
# int_rate                                        1
# installment                     0.950004                    1
# annual_inc                                                             1
# dti                                                                        1
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                delinq_2yrs inq_last_6mths  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs                              1
# inq_last_6mths                                          1
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                mths_since_last_delinq mths_since_last_record  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq                              1
# mths_since_last_record                                                     1
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq               0.859438
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                 open_acc pub_rec revol_bal revol_util  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc                               1
# pub_rec                                        1
# revol_bal                                                1
# revol_util                                                          1
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim                                  0.833575
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util                                                      0.858375
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl                   0.833676
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats                        0.998651
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                total_acc last_pymnt_amnt  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc                              1
# last_pymnt_amnt                                        1
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                mths_since_last_major_derog policy_code  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog                              1
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                acc_now_delinq tot_coll_amt tot_cur_bal  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq                              1
# tot_coll_amt                                             1
# tot_cur_bal                                                          1
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal                                                   0.832944
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd                         0.811237
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim                                               0.971236
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                open_acc_6m open_il_6m open_il_12m open_il_24m  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m                              1
# open_il_6m                                          1
# open_il_12m                                                     1
# open_il_24m                                                                 1
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                mths_since_rcnt_il total_bal_il il_util  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il                              1
# total_bal_il                                                 1
# il_util                                                              1
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort                                     0.893174
# total_bc_limit
# total_il_high_credit_limit                            0.956908
#
# ...
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util                                0.845079
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75                              1
# pub_rec_bankruptcies                                               1
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
#
#                                tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal                                     0.971236
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il                                                      0.893174
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens                              1
# tot_hi_cred_lim                                        1
# total_bal_ex_mort                                                        1
# total_bc_limit
# total_il_high_credit_limit                                        0.879395
#
#                                total_bc_limit total_il_high_credit_limit
# loan_amnt
# int_rate
# installment
# annual_inc
# dti
# delinq_2yrs
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# last_pymnt_amnt
# mths_since_last_major_derog
# policy_code
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il                                                    0.956908
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy                       0.823009
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort                                               0.879395
# total_bc_limit                              1
# total_il_high_credit_limit                                             1

# %%
df1 = df0.drop(['loan_amnt', 'mths_since_last_delinq', 'mths_since_last_record', 'last_pymnt_amnt', 'open_acc', 'revol_util', 'revol_bal', 'acc_now_delinq', 'tot_cur_bal', 'total_bal_il', 'open_rv_12m' ,'open_rv_24m', 'bc_open_to_buy', 'bc_util', 'mths_since_recent_bc_dlq', 'num_actv_bc_tl', 'num_bc_tl', 'num_op_rev_tl', 'total_bal_ex_mort', 'num_actv_rev_tl'], axis=1)

# %%
df1.corr()[(df1.corr() >= 0.8) | (df1.corr() <= -0.8)]
# Out:
#                                 int_rate  installment  annual_inc  dti  \
# int_rate                             1.0          NaN         NaN  NaN
# installment                          NaN          1.0         NaN  NaN
# annual_inc                           NaN          NaN         1.0  NaN
# dti                                  NaN          NaN         NaN  1.0
# delinq_2yrs                          NaN          NaN         NaN  NaN
# inq_last_6mths                       NaN          NaN         NaN  NaN
# pub_rec                              NaN          NaN         NaN  NaN
# total_acc                            NaN          NaN         NaN  NaN
# mths_since_last_major_derog          NaN          NaN         NaN  NaN
# policy_code                          NaN          NaN         NaN  NaN
# tot_coll_amt                         NaN          NaN         NaN  NaN
# open_acc_6m                          NaN          NaN         NaN  NaN
# open_il_6m                           NaN          NaN         NaN  NaN
# open_il_12m                          NaN          NaN         NaN  NaN
# open_il_24m                          NaN          NaN         NaN  NaN
# mths_since_rcnt_il                   NaN          NaN         NaN  NaN
# il_util                              NaN          NaN         NaN  NaN
# max_bal_bc                           NaN          NaN         NaN  NaN
# all_util                             NaN          NaN         NaN  NaN
# total_rev_hi_lim                     NaN          NaN         NaN  NaN
# inq_fi                               NaN          NaN         NaN  NaN
# total_cu_tl                          NaN          NaN         NaN  NaN
# inq_last_12m                         NaN          NaN         NaN  NaN
# acc_open_past_24mths                 NaN          NaN         NaN  NaN
# avg_cur_bal                          NaN          NaN         NaN  NaN
# chargeoff_within_12_mths             NaN          NaN         NaN  NaN
# delinq_amnt                          NaN          NaN         NaN  NaN
# mo_sin_old_il_acct                   NaN          NaN         NaN  NaN
# mo_sin_old_rev_tl_op                 NaN          NaN         NaN  NaN
# mo_sin_rcnt_rev_tl_op                NaN          NaN         NaN  NaN
# mo_sin_rcnt_tl                       NaN          NaN         NaN  NaN
# mort_acc                             NaN          NaN         NaN  NaN
# mths_since_recent_bc                 NaN          NaN         NaN  NaN
# mths_since_recent_inq                NaN          NaN         NaN  NaN
# mths_since_recent_revol_delinq       NaN          NaN         NaN  NaN
# num_accts_ever_120_pd                NaN          NaN         NaN  NaN
# num_bc_sats                          NaN          NaN         NaN  NaN
# num_il_tl                            NaN          NaN         NaN  NaN
# num_rev_accts                        NaN          NaN         NaN  NaN
# num_rev_tl_bal_gt_0                  NaN          NaN         NaN  NaN
# num_sats                             NaN          NaN         NaN  NaN
# num_tl_120dpd_2m                     NaN          NaN         NaN  NaN
# num_tl_30dpd                         NaN          NaN         NaN  NaN
# num_tl_90g_dpd_24m                   NaN          NaN         NaN  NaN
# num_tl_op_past_12m                   NaN          NaN         NaN  NaN
# pct_tl_nvr_dlq                       NaN          NaN         NaN  NaN
# percent_bc_gt_75                     NaN          NaN         NaN  NaN
# pub_rec_bankruptcies                 NaN          NaN         NaN  NaN
# tax_liens                            NaN          NaN         NaN  NaN
# tot_hi_cred_lim                      NaN          NaN         NaN  NaN
# total_bc_limit                       NaN          NaN         NaN  NaN
# total_il_high_credit_limit           NaN          NaN         NaN  NaN
#
#                                 delinq_2yrs  inq_last_6mths  pub_rec  \
# int_rate                                NaN             NaN      NaN
# installment                             NaN             NaN      NaN
# annual_inc                              NaN             NaN      NaN
# dti                                     NaN             NaN      NaN
# delinq_2yrs                             1.0             NaN      NaN
# inq_last_6mths                          NaN             1.0      NaN
# pub_rec                                 NaN             NaN      1.0
# total_acc                               NaN             NaN      NaN
# mths_since_last_major_derog             NaN             NaN      NaN
# policy_code                             NaN             NaN      NaN
# tot_coll_amt                            NaN             NaN      NaN
# open_acc_6m                             NaN             NaN      NaN
# open_il_6m                              NaN             NaN      NaN
# open_il_12m                             NaN             NaN      NaN
# open_il_24m                             NaN             NaN      NaN
# mths_since_rcnt_il                      NaN             NaN      NaN
# il_util                                 NaN             NaN      NaN
# max_bal_bc                              NaN             NaN      NaN
# all_util                                NaN             NaN      NaN
# total_rev_hi_lim                        NaN             NaN      NaN
# inq_fi                                  NaN             NaN      NaN
# total_cu_tl                             NaN             NaN      NaN
# inq_last_12m                            NaN             NaN      NaN
# acc_open_past_24mths                    NaN             NaN      NaN
# avg_cur_bal                             NaN             NaN      NaN
# chargeoff_within_12_mths                NaN             NaN      NaN
# delinq_amnt                             NaN             NaN      NaN
# mo_sin_old_il_acct                      NaN             NaN      NaN
# mo_sin_old_rev_tl_op                    NaN             NaN      NaN
# mo_sin_rcnt_rev_tl_op                   NaN             NaN      NaN
# mo_sin_rcnt_tl                          NaN             NaN      NaN
# mort_acc                                NaN             NaN      NaN
# mths_since_recent_bc                    NaN             NaN      NaN
# mths_since_recent_inq                   NaN             NaN      NaN
# mths_since_recent_revol_delinq          NaN             NaN      NaN
# num_accts_ever_120_pd                   NaN             NaN      NaN
# num_bc_sats                             NaN             NaN      NaN
# num_il_tl                               NaN             NaN      NaN
# num_rev_accts                           NaN             NaN      NaN
# num_rev_tl_bal_gt_0                     NaN             NaN      NaN
# num_sats                                NaN             NaN      NaN
# num_tl_120dpd_2m                        NaN             NaN      NaN
# num_tl_30dpd                            NaN             NaN      NaN
# num_tl_90g_dpd_24m                      NaN             NaN      NaN
# num_tl_op_past_12m                      NaN             NaN      NaN
# pct_tl_nvr_dlq                          NaN             NaN      NaN
# percent_bc_gt_75                        NaN             NaN      NaN
# pub_rec_bankruptcies                    NaN             NaN      NaN
# tax_liens                               NaN             NaN      NaN
# tot_hi_cred_lim                         NaN             NaN      NaN
# total_bc_limit                          NaN             NaN      NaN
# total_il_high_credit_limit              NaN             NaN      NaN
#
#                                 total_acc  mths_since_last_major_derog  \
# int_rate                              NaN                          NaN
# installment                           NaN                          NaN
# annual_inc                            NaN                          NaN
# dti                                   NaN                          NaN
# delinq_2yrs                           NaN                          NaN
# inq_last_6mths                        NaN                          NaN
# pub_rec                               NaN                          NaN
# total_acc                             1.0                          NaN
# mths_since_last_major_derog           NaN                          1.0
# policy_code                           NaN                          NaN
# tot_coll_amt                          NaN                          NaN
# open_acc_6m                           NaN                          NaN
# open_il_6m                            NaN                          NaN
# open_il_12m                           NaN                          NaN
# open_il_24m                           NaN                          NaN
# mths_since_rcnt_il                    NaN                          NaN
# il_util                               NaN                          NaN
# max_bal_bc                            NaN                          NaN
# all_util                              NaN                          NaN
# total_rev_hi_lim                      NaN                          NaN
# inq_fi                                NaN                          NaN
# total_cu_tl                           NaN                          NaN
# inq_last_12m                          NaN                          NaN
# acc_open_past_24mths                  NaN                          NaN
# avg_cur_bal                           NaN                          NaN
# chargeoff_within_12_mths              NaN                          NaN
# delinq_amnt                           NaN                          NaN
# mo_sin_old_il_acct                    NaN                          NaN
# mo_sin_old_rev_tl_op                  NaN                          NaN
# mo_sin_rcnt_rev_tl_op                 NaN                          NaN
# mo_sin_rcnt_tl                        NaN                          NaN
# mort_acc                              NaN                          NaN
# mths_since_recent_bc                  NaN                          NaN
# mths_since_recent_inq                 NaN                          NaN
# mths_since_recent_revol_delinq        NaN                          NaN
# num_accts_ever_120_pd                 NaN                          NaN
# num_bc_sats                           NaN                          NaN
# num_il_tl                             NaN                          NaN
# num_rev_accts                         NaN                          NaN
# num_rev_tl_bal_gt_0                   NaN                          NaN
# num_sats                              NaN                          NaN
# num_tl_120dpd_2m                      NaN                          NaN
# num_tl_30dpd                          NaN                          NaN
# num_tl_90g_dpd_24m                    NaN                          NaN
# num_tl_op_past_12m                    NaN                          NaN
# pct_tl_nvr_dlq                        NaN                          NaN
# percent_bc_gt_75                      NaN                          NaN
# pub_rec_bankruptcies                  NaN                          NaN
# tax_liens                             NaN                          NaN
# tot_hi_cred_lim                       NaN                          NaN
# total_bc_limit                        NaN                          NaN
# total_il_high_credit_limit            NaN                          NaN
#
#                                 policy_code  tot_coll_amt  open_acc_6m  \
# int_rate                                NaN           NaN          NaN
# installment                             NaN           NaN          NaN
# annual_inc                              NaN           NaN          NaN
# dti                                     NaN           NaN          NaN
# delinq_2yrs                             NaN           NaN          NaN
# inq_last_6mths                          NaN           NaN          NaN
# pub_rec                                 NaN           NaN          NaN
# total_acc                               NaN           NaN          NaN
# mths_since_last_major_derog             NaN           NaN          NaN
# policy_code                             NaN           NaN          NaN
# tot_coll_amt                            NaN           1.0          NaN
# open_acc_6m                             NaN           NaN          1.0
# open_il_6m                              NaN           NaN          NaN
# open_il_12m                             NaN           NaN          NaN
# open_il_24m                             NaN           NaN          NaN
# mths_since_rcnt_il                      NaN           NaN          NaN
# il_util                                 NaN           NaN          NaN
# max_bal_bc                              NaN           NaN          NaN
# all_util                                NaN           NaN          NaN
# total_rev_hi_lim                        NaN           NaN          NaN
# inq_fi                                  NaN           NaN          NaN
# total_cu_tl                             NaN           NaN          NaN
# inq_last_12m                            NaN           NaN          NaN
# acc_open_past_24mths                    NaN           NaN          NaN
# avg_cur_bal                             NaN           NaN          NaN
# chargeoff_within_12_mths                NaN           NaN          NaN
# delinq_amnt                             NaN           NaN          NaN
# mo_sin_old_il_acct                      NaN           NaN          NaN
# mo_sin_old_rev_tl_op                    NaN           NaN          NaN
# mo_sin_rcnt_rev_tl_op                   NaN           NaN          NaN
# mo_sin_rcnt_tl                          NaN           NaN          NaN
# mort_acc                                NaN           NaN          NaN
# mths_since_recent_bc                    NaN           NaN          NaN
# mths_since_recent_inq                   NaN           NaN          NaN
# mths_since_recent_revol_delinq          NaN           NaN          NaN
# num_accts_ever_120_pd                   NaN           NaN          NaN
# num_bc_sats                             NaN           NaN          NaN
# num_il_tl                               NaN           NaN          NaN
# num_rev_accts                           NaN           NaN          NaN
# num_rev_tl_bal_gt_0                     NaN           NaN          NaN
# num_sats                                NaN           NaN          NaN
# num_tl_120dpd_2m                        NaN           NaN          NaN
# num_tl_30dpd                            NaN           NaN          NaN
# num_tl_90g_dpd_24m                      NaN           NaN          NaN
# num_tl_op_past_12m                      NaN           NaN          NaN
# pct_tl_nvr_dlq                          NaN           NaN          NaN
# percent_bc_gt_75                        NaN           NaN          NaN
# pub_rec_bankruptcies                    NaN           NaN          NaN
# tax_liens                               NaN           NaN          NaN
# tot_hi_cred_lim                         NaN           NaN          NaN
# total_bc_limit                          NaN           NaN          NaN
# total_il_high_credit_limit              NaN           NaN          NaN
#
#                                 open_il_6m  open_il_12m  open_il_24m  \
# int_rate                               NaN          NaN          NaN
# installment                            NaN          NaN          NaN
# annual_inc                             NaN          NaN          NaN
# dti                                    NaN          NaN          NaN
# delinq_2yrs                            NaN          NaN          NaN
# inq_last_6mths                         NaN          NaN          NaN
# pub_rec                                NaN          NaN          NaN
# total_acc                              NaN          NaN          NaN
# mths_since_last_major_derog            NaN          NaN          NaN
# policy_code                            NaN          NaN          NaN
# tot_coll_amt                           NaN          NaN          NaN
# open_acc_6m                            NaN          NaN          NaN
# open_il_6m                             1.0          NaN          NaN
# open_il_12m                            NaN          1.0          NaN
# open_il_24m                            NaN          NaN          1.0
# mths_since_rcnt_il                     NaN          NaN          NaN
# il_util                                NaN          NaN          NaN
# max_bal_bc                             NaN          NaN          NaN
# all_util                               NaN          NaN          NaN
# total_rev_hi_lim                       NaN          NaN          NaN
# inq_fi                                 NaN          NaN          NaN
# total_cu_tl                            NaN          NaN          NaN
# inq_last_12m                           NaN          NaN          NaN
# acc_open_past_24mths                   NaN          NaN          NaN
# avg_cur_bal                            NaN          NaN          NaN
# chargeoff_within_12_mths               NaN          NaN          NaN
# delinq_amnt                            NaN          NaN          NaN
# mo_sin_old_il_acct                     NaN          NaN          NaN
# mo_sin_old_rev_tl_op                   NaN          NaN          NaN
# mo_sin_rcnt_rev_tl_op                  NaN          NaN          NaN
# mo_sin_rcnt_tl                         NaN          NaN          NaN
# mort_acc                               NaN          NaN          NaN
# mths_since_recent_bc                   NaN          NaN          NaN
# mths_since_recent_inq                  NaN          NaN          NaN
# mths_since_recent_revol_delinq         NaN          NaN          NaN
# num_accts_ever_120_pd                  NaN          NaN          NaN
# num_bc_sats                            NaN          NaN          NaN
# num_il_tl                              NaN          NaN          NaN
# num_rev_accts                          NaN          NaN          NaN
# num_rev_tl_bal_gt_0                    NaN          NaN          NaN
# num_sats                               NaN          NaN          NaN
# num_tl_120dpd_2m                       NaN          NaN          NaN
# num_tl_30dpd                           NaN          NaN          NaN
# num_tl_90g_dpd_24m                     NaN          NaN          NaN
# num_tl_op_past_12m                     NaN          NaN          NaN
# pct_tl_nvr_dlq                         NaN          NaN          NaN
# percent_bc_gt_75                       NaN          NaN          NaN
# pub_rec_bankruptcies                   NaN          NaN          NaN
# tax_liens                              NaN          NaN          NaN
# tot_hi_cred_lim                        NaN          NaN          NaN
# total_bc_limit                         NaN          NaN          NaN
# total_il_high_credit_limit             NaN          NaN          NaN
#
#                                 mths_since_rcnt_il  il_util  max_bal_bc  \
# int_rate                                       NaN      NaN         NaN
# installment                                    NaN      NaN         NaN
# annual_inc                                     NaN      NaN         NaN
# dti                                            NaN      NaN         NaN
# delinq_2yrs                                    NaN      NaN         NaN
# inq_last_6mths                                 NaN      NaN         NaN
# pub_rec                                        NaN      NaN         NaN
# total_acc                                      NaN      NaN         NaN
# mths_since_last_major_derog                    NaN      NaN         NaN
# policy_code                                    NaN      NaN         NaN
# tot_coll_amt                                   NaN      NaN         NaN
# open_acc_6m                                    NaN      NaN         NaN
# open_il_6m                                     NaN      NaN         NaN
# open_il_12m                                    NaN      NaN         NaN
# open_il_24m                                    NaN      NaN         NaN
# mths_since_rcnt_il                             1.0      NaN         NaN
# il_util                                        NaN      1.0         NaN
# max_bal_bc                                     NaN      NaN         1.0
# all_util                                       NaN      NaN         NaN
# total_rev_hi_lim                               NaN      NaN         NaN
# inq_fi                                         NaN      NaN         NaN
# total_cu_tl                                    NaN      NaN         NaN
# inq_last_12m                                   NaN      NaN         NaN
# acc_open_past_24mths                           NaN      NaN         NaN
# avg_cur_bal                                    NaN      NaN         NaN
# chargeoff_within_12_mths                       NaN      NaN         NaN
# delinq_amnt                                    NaN      NaN         NaN
# mo_sin_old_il_acct                             NaN      NaN         NaN
# mo_sin_old_rev_tl_op                           NaN      NaN         NaN
# mo_sin_rcnt_rev_tl_op                          NaN      NaN         NaN
# mo_sin_rcnt_tl                                 NaN      NaN         NaN
# mort_acc                                       NaN      NaN         NaN
# mths_since_recent_bc                           NaN      NaN         NaN
# mths_since_recent_inq                          NaN      NaN         NaN
# mths_since_recent_revol_delinq                 NaN      NaN         NaN
# num_accts_ever_120_pd                          NaN      NaN         NaN
# num_bc_sats                                    NaN      NaN         NaN
# num_il_tl                                      NaN      NaN         NaN
# num_rev_accts                                  NaN      NaN         NaN
# num_rev_tl_bal_gt_0                            NaN      NaN         NaN
# num_sats                                       NaN      NaN         NaN
# num_tl_120dpd_2m                               NaN      NaN         NaN
# num_tl_30dpd                                   NaN      NaN         NaN
# num_tl_90g_dpd_24m                             NaN      NaN         NaN
# num_tl_op_past_12m                             NaN      NaN         NaN
# pct_tl_nvr_dlq                                 NaN      NaN         NaN
# percent_bc_gt_75                               NaN      NaN         NaN
# pub_rec_bankruptcies                           NaN      NaN         NaN
# tax_liens                                      NaN      NaN         NaN
# tot_hi_cred_lim                                NaN      NaN         NaN
# total_bc_limit                                 NaN      NaN         NaN
# total_il_high_credit_limit                     NaN      NaN         NaN
#
#                                 all_util  total_rev_hi_lim  inq_fi  \
# int_rate                             NaN               NaN     NaN
# installment                          NaN               NaN     NaN
# annual_inc                           NaN               NaN     NaN
# dti                                  NaN               NaN     NaN
# delinq_2yrs                          NaN               NaN     NaN
# inq_last_6mths                       NaN               NaN     NaN
# pub_rec                              NaN               NaN     NaN
# total_acc                            NaN               NaN     NaN
# mths_since_last_major_derog          NaN               NaN     NaN
# policy_code                          NaN               NaN     NaN
# tot_coll_amt                         NaN               NaN     NaN
# open_acc_6m                          NaN               NaN     NaN
# open_il_6m                           NaN               NaN     NaN
# open_il_12m                          NaN               NaN     NaN
# open_il_24m                          NaN               NaN     NaN
# mths_since_rcnt_il                   NaN               NaN     NaN
# il_util                              NaN               NaN     NaN
# max_bal_bc                           NaN               NaN     NaN
# all_util                             1.0               NaN     NaN
# total_rev_hi_lim                     NaN               1.0     NaN
# inq_fi                               NaN               NaN     1.0
# total_cu_tl                          NaN               NaN     NaN
# inq_last_12m                         NaN               NaN     NaN
# acc_open_past_24mths                 NaN               NaN     NaN
# avg_cur_bal                          NaN               NaN     NaN
# chargeoff_within_12_mths             NaN               NaN     NaN
# delinq_amnt                          NaN               NaN     NaN
# mo_sin_old_il_acct                   NaN               NaN     NaN
# mo_sin_old_rev_tl_op                 NaN               NaN     NaN
# mo_sin_rcnt_rev_tl_op                NaN               NaN     NaN
# mo_sin_rcnt_tl                       NaN               NaN     NaN
# mort_acc                             NaN               NaN     NaN
# mths_since_recent_bc                 NaN               NaN     NaN
# mths_since_recent_inq                NaN               NaN     NaN
# mths_since_recent_revol_delinq       NaN               NaN     NaN
# num_accts_ever_120_pd                NaN               NaN     NaN
# num_bc_sats                          NaN               NaN     NaN
# num_il_tl                            NaN               NaN     NaN
# num_rev_accts                        NaN               NaN     NaN
# num_rev_tl_bal_gt_0                  NaN               NaN     NaN
# num_sats                             NaN               NaN     NaN
# num_tl_120dpd_2m                     NaN               NaN     NaN
# num_tl_30dpd                         NaN               NaN     NaN
# num_tl_90g_dpd_24m                   NaN               NaN     NaN
# num_tl_op_past_12m                   NaN               NaN     NaN
# pct_tl_nvr_dlq                       NaN               NaN     NaN
# percent_bc_gt_75                     NaN               NaN     NaN
# pub_rec_bankruptcies                 NaN               NaN     NaN
# tax_liens                            NaN               NaN     NaN
# tot_hi_cred_lim                      NaN               NaN     NaN
# total_bc_limit                       NaN               NaN     NaN
# total_il_high_credit_limit           NaN               NaN     NaN
#
#                                 total_cu_tl  inq_last_12m  \
# int_rate                                NaN           NaN
# installment                             NaN           NaN
# annual_inc                              NaN           NaN
# dti                                     NaN           NaN
# delinq_2yrs                             NaN           NaN
# inq_last_6mths                          NaN           NaN
# pub_rec                                 NaN           NaN
# total_acc                               NaN           NaN
# mths_since_last_major_derog             NaN           NaN
# policy_code                             NaN           NaN
# tot_coll_amt                            NaN           NaN
# open_acc_6m                             NaN           NaN
# open_il_6m                              NaN           NaN
# open_il_12m                             NaN           NaN
# open_il_24m                             NaN           NaN
# mths_since_rcnt_il                      NaN           NaN
# il_util                                 NaN           NaN
# max_bal_bc                              NaN           NaN
# all_util                                NaN           NaN
# total_rev_hi_lim                        NaN           NaN
# inq_fi                                  NaN           NaN
# total_cu_tl                             1.0           NaN
# inq_last_12m                            NaN           1.0
# acc_open_past_24mths                    NaN           NaN
# avg_cur_bal                             NaN           NaN
# chargeoff_within_12_mths                NaN           NaN
# delinq_amnt                             NaN           NaN
# mo_sin_old_il_acct                      NaN           NaN
# mo_sin_old_rev_tl_op                    NaN           NaN
# mo_sin_rcnt_rev_tl_op                   NaN           NaN
# mo_sin_rcnt_tl                          NaN           NaN
# mort_acc                                NaN           NaN
# mths_since_recent_bc                    NaN           NaN
# mths_since_recent_inq                   NaN           NaN
# mths_since_recent_revol_delinq          NaN           NaN
# num_accts_ever_120_pd                   NaN           NaN
# num_bc_sats                             NaN           NaN
# num_il_tl                               NaN           NaN
# num_rev_accts                           NaN           NaN
# num_rev_tl_bal_gt_0                     NaN           NaN
# num_sats                                NaN           NaN
# num_tl_120dpd_2m                        NaN           NaN
# num_tl_30dpd                            NaN           NaN
# num_tl_90g_dpd_24m                      NaN           NaN
# num_tl_op_past_12m                      NaN           NaN
# pct_tl_nvr_dlq                          NaN           NaN
# percent_bc_gt_75                        NaN           NaN
# pub_rec_bankruptcies                    NaN           NaN
# tax_liens                               NaN           NaN
# tot_hi_cred_lim                         NaN           NaN
# total_bc_limit                          NaN           NaN
# total_il_high_credit_limit              NaN           NaN
#
#                                 acc_open_past_24mths  avg_cur_bal  \
# int_rate                                         NaN          NaN
# installment                                      NaN          NaN
# annual_inc                                       NaN          NaN
# dti                                              NaN          NaN
# delinq_2yrs                                      NaN          NaN
# inq_last_6mths                                   NaN          NaN
# pub_rec                                          NaN          NaN
# total_acc                                        NaN          NaN
# mths_since_last_major_derog                      NaN          NaN
# policy_code                                      NaN          NaN
# tot_coll_amt                                     NaN          NaN
# open_acc_6m                                      NaN          NaN
# open_il_6m                                       NaN          NaN
# open_il_12m                                      NaN          NaN
# open_il_24m                                      NaN          NaN
# mths_since_rcnt_il                               NaN          NaN
# il_util                                          NaN          NaN
# max_bal_bc                                       NaN          NaN
# all_util                                         NaN          NaN
# total_rev_hi_lim                                 NaN          NaN
# inq_fi                                           NaN          NaN
# total_cu_tl                                      NaN          NaN
# inq_last_12m                                     NaN          NaN
# acc_open_past_24mths                             1.0          NaN
# avg_cur_bal                                      NaN          1.0
# chargeoff_within_12_mths                         NaN          NaN
# delinq_amnt                                      NaN          NaN
# mo_sin_old_il_acct                               NaN          NaN
# mo_sin_old_rev_tl_op                             NaN          NaN
# mo_sin_rcnt_rev_tl_op                            NaN          NaN
# mo_sin_rcnt_tl                                   NaN          NaN
# mort_acc                                         NaN          NaN
# mths_since_recent_bc                             NaN          NaN
# mths_since_recent_inq                            NaN          NaN
# mths_since_recent_revol_delinq                   NaN          NaN
# num_accts_ever_120_pd                            NaN          NaN
# num_bc_sats                                      NaN          NaN
# num_il_tl                                        NaN          NaN
# num_rev_accts                                    NaN          NaN
# num_rev_tl_bal_gt_0                              NaN          NaN
# num_sats                                         NaN          NaN
# num_tl_120dpd_2m                                 NaN          NaN
# num_tl_30dpd                                     NaN          NaN
# num_tl_90g_dpd_24m                               NaN          NaN
# num_tl_op_past_12m                               NaN          NaN
# pct_tl_nvr_dlq                                   NaN          NaN
# percent_bc_gt_75                                 NaN          NaN
# pub_rec_bankruptcies                             NaN          NaN
# tax_liens                                        NaN          NaN
# tot_hi_cred_lim                                  NaN          NaN
# total_bc_limit                                   NaN          NaN
# total_il_high_credit_limit                       NaN          NaN
#
#                                 chargeoff_within_12_mths  delinq_amnt  \
# int_rate                                             NaN          NaN
# installment                                          NaN          NaN
# annual_inc                                           NaN          NaN
# dti                                                  NaN          NaN
# delinq_2yrs                                          NaN          NaN
# inq_last_6mths                                       NaN          NaN
# pub_rec                                              NaN          NaN
# total_acc                                            NaN          NaN
# mths_since_last_major_derog                          NaN          NaN
# policy_code                                          NaN          NaN
# tot_coll_amt                                         NaN          NaN
# open_acc_6m                                          NaN          NaN
# open_il_6m                                           NaN          NaN
# open_il_12m                                          NaN          NaN
# open_il_24m                                          NaN          NaN
# mths_since_rcnt_il                                   NaN          NaN
# il_util                                              NaN          NaN
# max_bal_bc                                           NaN          NaN
# all_util                                             NaN          NaN
# total_rev_hi_lim                                     NaN          NaN
# inq_fi                                               NaN          NaN
# total_cu_tl                                          NaN          NaN
# inq_last_12m                                         NaN          NaN
# acc_open_past_24mths                                 NaN          NaN
# avg_cur_bal                                          NaN          NaN
# chargeoff_within_12_mths                             1.0          NaN
# delinq_amnt                                          NaN          1.0
# mo_sin_old_il_acct                                   NaN          NaN
# mo_sin_old_rev_tl_op                                 NaN          NaN
# mo_sin_rcnt_rev_tl_op                                NaN          NaN
# mo_sin_rcnt_tl                                       NaN          NaN
# mort_acc                                             NaN          NaN
# mths_since_recent_bc                                 NaN          NaN
# mths_since_recent_inq                                NaN          NaN
# mths_since_recent_revol_delinq                       NaN          NaN
# num_accts_ever_120_pd                                NaN          NaN
# num_bc_sats                                          NaN          NaN
# num_il_tl                                            NaN          NaN
# num_rev_accts                                        NaN          NaN
# num_rev_tl_bal_gt_0                                  NaN          NaN
# num_sats                                             NaN          NaN
# num_tl_120dpd_2m                                     NaN          NaN
# num_tl_30dpd                                         NaN          NaN
# num_tl_90g_dpd_24m                                   NaN          NaN
# num_tl_op_past_12m                                   NaN          NaN
# pct_tl_nvr_dlq                                       NaN          NaN
# percent_bc_gt_75                                     NaN          NaN
# pub_rec_bankruptcies                                 NaN          NaN
# tax_liens                                            NaN          NaN
# tot_hi_cred_lim                                      NaN          NaN
# total_bc_limit                                       NaN          NaN
# total_il_high_credit_limit                           NaN          NaN
#
#                                 mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# int_rate                                       NaN                   NaN
# installment                                    NaN                   NaN
# annual_inc                                     NaN                   NaN
# dti                                            NaN                   NaN
# delinq_2yrs                                    NaN                   NaN
# inq_last_6mths                                 NaN                   NaN
# pub_rec                                        NaN                   NaN
# total_acc                                      NaN                   NaN
# mths_since_last_major_derog                    NaN                   NaN
# policy_code                                    NaN                   NaN
# tot_coll_amt                                   NaN                   NaN
# open_acc_6m                                    NaN                   NaN
# open_il_6m                                     NaN                   NaN
# open_il_12m                                    NaN                   NaN
# open_il_24m                                    NaN                   NaN
# mths_since_rcnt_il                             NaN                   NaN
# il_util                                        NaN                   NaN
# max_bal_bc                                     NaN                   NaN
# all_util                                       NaN                   NaN
# total_rev_hi_lim                               NaN                   NaN
# inq_fi                                         NaN                   NaN
# total_cu_tl                                    NaN                   NaN
# inq_last_12m                                   NaN                   NaN
# acc_open_past_24mths                           NaN                   NaN
# avg_cur_bal                                    NaN                   NaN
# chargeoff_within_12_mths                       NaN                   NaN
# delinq_amnt                                    NaN                   NaN
# mo_sin_old_il_acct                             1.0                   NaN
# mo_sin_old_rev_tl_op                           NaN                   1.0
# mo_sin_rcnt_rev_tl_op                          NaN                   NaN
# mo_sin_rcnt_tl                                 NaN                   NaN
# mort_acc                                       NaN                   NaN
# mths_since_recent_bc                           NaN                   NaN
# mths_since_recent_inq                          NaN                   NaN
# mths_since_recent_revol_delinq                 NaN                   NaN
# num_accts_ever_120_pd                          NaN                   NaN
# num_bc_sats                                    NaN                   NaN
# num_il_tl                                      NaN                   NaN
# num_rev_accts                                  NaN                   NaN
# num_rev_tl_bal_gt_0                            NaN                   NaN
# num_sats                                       NaN                   NaN
# num_tl_120dpd_2m                               NaN                   NaN
# num_tl_30dpd                                   NaN                   NaN
# num_tl_90g_dpd_24m                             NaN                   NaN
# num_tl_op_past_12m                             NaN                   NaN
# pct_tl_nvr_dlq                                 NaN                   NaN
# percent_bc_gt_75                               NaN                   NaN
# pub_rec_bankruptcies                           NaN                   NaN
# tax_liens                                      NaN                   NaN
# tot_hi_cred_lim                                NaN                   NaN
# total_bc_limit                                 NaN                   NaN
# total_il_high_credit_limit                     NaN                   NaN
#
#                                 mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  \
# int_rate                                          NaN             NaN
# installment                                       NaN             NaN
# annual_inc                                        NaN             NaN
# dti                                               NaN             NaN
# delinq_2yrs                                       NaN             NaN
# inq_last_6mths                                    NaN             NaN
# pub_rec                                           NaN             NaN
# total_acc                                         NaN             NaN
# mths_since_last_major_derog                       NaN             NaN
# policy_code                                       NaN             NaN
# tot_coll_amt                                      NaN             NaN
# open_acc_6m                                       NaN             NaN
# open_il_6m                                        NaN             NaN
# open_il_12m                                       NaN             NaN
# open_il_24m                                       NaN             NaN
# mths_since_rcnt_il                                NaN             NaN
# il_util                                           NaN             NaN
# max_bal_bc                                        NaN             NaN
# all_util                                          NaN             NaN
# total_rev_hi_lim                                  NaN             NaN
# inq_fi                                            NaN             NaN
# total_cu_tl                                       NaN             NaN
# inq_last_12m                                      NaN             NaN
# acc_open_past_24mths                              NaN             NaN
# avg_cur_bal                                       NaN             NaN
# chargeoff_within_12_mths                          NaN             NaN
# delinq_amnt                                       NaN             NaN
# mo_sin_old_il_acct                                NaN             NaN
# mo_sin_old_rev_tl_op                              NaN             NaN
# mo_sin_rcnt_rev_tl_op                             1.0             NaN
# mo_sin_rcnt_tl                                    NaN             1.0
# mort_acc                                          NaN             NaN
# mths_since_recent_bc                              NaN             NaN
# mths_since_recent_inq                             NaN             NaN
# mths_since_recent_revol_delinq                    NaN             NaN
# num_accts_ever_120_pd                             NaN             NaN
# num_bc_sats                                       NaN             NaN
# num_il_tl                                         NaN             NaN
# num_rev_accts                                     NaN             NaN
# num_rev_tl_bal_gt_0                               NaN             NaN
# num_sats                                          NaN             NaN
# num_tl_120dpd_2m                                  NaN             NaN
# num_tl_30dpd                                      NaN             NaN
# num_tl_90g_dpd_24m                                NaN             NaN
# num_tl_op_past_12m                                NaN             NaN
# pct_tl_nvr_dlq                                    NaN             NaN
# percent_bc_gt_75                                  NaN             NaN
# pub_rec_bankruptcies                              NaN             NaN
# tax_liens                                         NaN             NaN
# tot_hi_cred_lim                                   NaN             NaN
# total_bc_limit                                    NaN             NaN
# total_il_high_credit_limit                        NaN             NaN
#
#                                 mort_acc  mths_since_recent_bc  \
# int_rate                             NaN                   NaN
# installment                          NaN                   NaN
# annual_inc                           NaN                   NaN
# dti                                  NaN                   NaN
# delinq_2yrs                          NaN                   NaN
# inq_last_6mths                       NaN                   NaN
# pub_rec                              NaN                   NaN
# total_acc                            NaN                   NaN
# mths_since_last_major_derog          NaN                   NaN
# policy_code                          NaN                   NaN
# tot_coll_amt                         NaN                   NaN
# open_acc_6m                          NaN                   NaN
# open_il_6m                           NaN                   NaN
# open_il_12m                          NaN                   NaN
# open_il_24m                          NaN                   NaN
# mths_since_rcnt_il                   NaN                   NaN
# il_util                              NaN                   NaN
# max_bal_bc                           NaN                   NaN
# all_util                             NaN                   NaN
# total_rev_hi_lim                     NaN                   NaN
# inq_fi                               NaN                   NaN
# total_cu_tl                          NaN                   NaN
# inq_last_12m                         NaN                   NaN
# acc_open_past_24mths                 NaN                   NaN
# avg_cur_bal                          NaN                   NaN
# chargeoff_within_12_mths             NaN                   NaN
# delinq_amnt                          NaN                   NaN
# mo_sin_old_il_acct                   NaN                   NaN
# mo_sin_old_rev_tl_op                 NaN                   NaN
# mo_sin_rcnt_rev_tl_op                NaN                   NaN
# mo_sin_rcnt_tl                       NaN                   NaN
# mort_acc                             1.0                   NaN
# mths_since_recent_bc                 NaN                   1.0
# ...
# chargeoff_within_12_mths                       NaN                 NaN
# delinq_amnt                                    NaN                 NaN
# mo_sin_old_il_acct                             NaN                 NaN
# mo_sin_old_rev_tl_op                           NaN                 NaN
# mo_sin_rcnt_rev_tl_op                          NaN                 NaN
# mo_sin_rcnt_tl                                 NaN                 NaN
# mort_acc                                       NaN                 NaN
# mths_since_recent_bc                           NaN                 NaN
# mths_since_recent_inq                          NaN                 NaN
# mths_since_recent_revol_delinq                 NaN                 NaN
# num_accts_ever_120_pd                          NaN                 NaN
# num_bc_sats                                    NaN                 NaN
# num_il_tl                                      NaN                 NaN
# num_rev_accts                                  NaN                 NaN
# num_rev_tl_bal_gt_0                            NaN                 NaN
# num_sats                                       NaN                 NaN
# num_tl_120dpd_2m                               NaN                 NaN
# num_tl_30dpd                                   NaN                 NaN
# num_tl_90g_dpd_24m                             1.0                 NaN
# num_tl_op_past_12m                             NaN                 1.0
# pct_tl_nvr_dlq                                 NaN                 NaN
# percent_bc_gt_75                               NaN                 NaN
# pub_rec_bankruptcies                           NaN                 NaN
# tax_liens                                      NaN                 NaN
# tot_hi_cred_lim                                NaN                 NaN
# total_bc_limit                                 NaN                 NaN
# total_il_high_credit_limit                     NaN                 NaN
#
#                                 pct_tl_nvr_dlq  percent_bc_gt_75  \
# int_rate                                   NaN               NaN
# installment                                NaN               NaN
# annual_inc                                 NaN               NaN
# dti                                        NaN               NaN
# delinq_2yrs                                NaN               NaN
# inq_last_6mths                             NaN               NaN
# pub_rec                                    NaN               NaN
# total_acc                                  NaN               NaN
# mths_since_last_major_derog                NaN               NaN
# policy_code                                NaN               NaN
# tot_coll_amt                               NaN               NaN
# open_acc_6m                                NaN               NaN
# open_il_6m                                 NaN               NaN
# open_il_12m                                NaN               NaN
# open_il_24m                                NaN               NaN
# mths_since_rcnt_il                         NaN               NaN
# il_util                                    NaN               NaN
# max_bal_bc                                 NaN               NaN
# all_util                                   NaN               NaN
# total_rev_hi_lim                           NaN               NaN
# inq_fi                                     NaN               NaN
# total_cu_tl                                NaN               NaN
# inq_last_12m                               NaN               NaN
# acc_open_past_24mths                       NaN               NaN
# avg_cur_bal                                NaN               NaN
# chargeoff_within_12_mths                   NaN               NaN
# delinq_amnt                                NaN               NaN
# mo_sin_old_il_acct                         NaN               NaN
# mo_sin_old_rev_tl_op                       NaN               NaN
# mo_sin_rcnt_rev_tl_op                      NaN               NaN
# mo_sin_rcnt_tl                             NaN               NaN
# mort_acc                                   NaN               NaN
# mths_since_recent_bc                       NaN               NaN
# mths_since_recent_inq                      NaN               NaN
# mths_since_recent_revol_delinq             NaN               NaN
# num_accts_ever_120_pd                      NaN               NaN
# num_bc_sats                                NaN               NaN
# num_il_tl                                  NaN               NaN
# num_rev_accts                              NaN               NaN
# num_rev_tl_bal_gt_0                        NaN               NaN
# num_sats                                   NaN               NaN
# num_tl_120dpd_2m                           NaN               NaN
# num_tl_30dpd                               NaN               NaN
# num_tl_90g_dpd_24m                         NaN               NaN
# num_tl_op_past_12m                         NaN               NaN
# pct_tl_nvr_dlq                             1.0               NaN
# percent_bc_gt_75                           NaN               1.0
# pub_rec_bankruptcies                       NaN               NaN
# tax_liens                                  NaN               NaN
# tot_hi_cred_lim                            NaN               NaN
# total_bc_limit                             NaN               NaN
# total_il_high_credit_limit                 NaN               NaN
#
#                                 pub_rec_bankruptcies  tax_liens  \
# int_rate                                         NaN        NaN
# installment                                      NaN        NaN
# annual_inc                                       NaN        NaN
# dti                                              NaN        NaN
# delinq_2yrs                                      NaN        NaN
# inq_last_6mths                                   NaN        NaN
# pub_rec                                          NaN        NaN
# total_acc                                        NaN        NaN
# mths_since_last_major_derog                      NaN        NaN
# policy_code                                      NaN        NaN
# tot_coll_amt                                     NaN        NaN
# open_acc_6m                                      NaN        NaN
# open_il_6m                                       NaN        NaN
# open_il_12m                                      NaN        NaN
# open_il_24m                                      NaN        NaN
# mths_since_rcnt_il                               NaN        NaN
# il_util                                          NaN        NaN
# max_bal_bc                                       NaN        NaN
# all_util                                         NaN        NaN
# total_rev_hi_lim                                 NaN        NaN
# inq_fi                                           NaN        NaN
# total_cu_tl                                      NaN        NaN
# inq_last_12m                                     NaN        NaN
# acc_open_past_24mths                             NaN        NaN
# avg_cur_bal                                      NaN        NaN
# chargeoff_within_12_mths                         NaN        NaN
# delinq_amnt                                      NaN        NaN
# mo_sin_old_il_acct                               NaN        NaN
# mo_sin_old_rev_tl_op                             NaN        NaN
# mo_sin_rcnt_rev_tl_op                            NaN        NaN
# mo_sin_rcnt_tl                                   NaN        NaN
# mort_acc                                         NaN        NaN
# mths_since_recent_bc                             NaN        NaN
# mths_since_recent_inq                            NaN        NaN
# mths_since_recent_revol_delinq                   NaN        NaN
# num_accts_ever_120_pd                            NaN        NaN
# num_bc_sats                                      NaN        NaN
# num_il_tl                                        NaN        NaN
# num_rev_accts                                    NaN        NaN
# num_rev_tl_bal_gt_0                              NaN        NaN
# num_sats                                         NaN        NaN
# num_tl_120dpd_2m                                 NaN        NaN
# num_tl_30dpd                                     NaN        NaN
# num_tl_90g_dpd_24m                               NaN        NaN
# num_tl_op_past_12m                               NaN        NaN
# pct_tl_nvr_dlq                                   NaN        NaN
# percent_bc_gt_75                                 NaN        NaN
# pub_rec_bankruptcies                             1.0        NaN
# tax_liens                                        NaN        1.0
# tot_hi_cred_lim                                  NaN        NaN
# total_bc_limit                                   NaN        NaN
# total_il_high_credit_limit                       NaN        NaN
#
#                                 tot_hi_cred_lim  total_bc_limit  \
# int_rate                                    NaN             NaN
# installment                                 NaN             NaN
# annual_inc                                  NaN             NaN
# dti                                         NaN             NaN
# delinq_2yrs                                 NaN             NaN
# inq_last_6mths                              NaN             NaN
# pub_rec                                     NaN             NaN
# total_acc                                   NaN             NaN
# mths_since_last_major_derog                 NaN             NaN
# policy_code                                 NaN             NaN
# tot_coll_amt                                NaN             NaN
# open_acc_6m                                 NaN             NaN
# open_il_6m                                  NaN             NaN
# open_il_12m                                 NaN             NaN
# open_il_24m                                 NaN             NaN
# mths_since_rcnt_il                          NaN             NaN
# il_util                                     NaN             NaN
# max_bal_bc                                  NaN             NaN
# all_util                                    NaN             NaN
# total_rev_hi_lim                            NaN             NaN
# inq_fi                                      NaN             NaN
# total_cu_tl                                 NaN             NaN
# inq_last_12m                                NaN             NaN
# acc_open_past_24mths                        NaN             NaN
# avg_cur_bal                                 NaN             NaN
# chargeoff_within_12_mths                    NaN             NaN
# delinq_amnt                                 NaN             NaN
# mo_sin_old_il_acct                          NaN             NaN
# mo_sin_old_rev_tl_op                        NaN             NaN
# mo_sin_rcnt_rev_tl_op                       NaN             NaN
# mo_sin_rcnt_tl                              NaN             NaN
# mort_acc                                    NaN             NaN
# mths_since_recent_bc                        NaN             NaN
# mths_since_recent_inq                       NaN             NaN
# mths_since_recent_revol_delinq              NaN             NaN
# num_accts_ever_120_pd                       NaN             NaN
# num_bc_sats                                 NaN             NaN
# num_il_tl                                   NaN             NaN
# num_rev_accts                               NaN             NaN
# num_rev_tl_bal_gt_0                         NaN             NaN
# num_sats                                    NaN             NaN
# num_tl_120dpd_2m                            NaN             NaN
# num_tl_30dpd                                NaN             NaN
# num_tl_90g_dpd_24m                          NaN             NaN
# num_tl_op_past_12m                          NaN             NaN
# pct_tl_nvr_dlq                              NaN             NaN
# percent_bc_gt_75                            NaN             NaN
# pub_rec_bankruptcies                        NaN             NaN
# tax_liens                                   NaN             NaN
# tot_hi_cred_lim                             1.0             NaN
# total_bc_limit                              NaN             1.0
# total_il_high_credit_limit                  NaN             NaN
#
#                                 total_il_high_credit_limit
# int_rate                                               NaN
# installment                                            NaN
# annual_inc                                             NaN
# dti                                                    NaN
# delinq_2yrs                                            NaN
# inq_last_6mths                                         NaN
# pub_rec                                                NaN
# total_acc                                              NaN
# mths_since_last_major_derog                            NaN
# policy_code                                            NaN
# tot_coll_amt                                           NaN
# open_acc_6m                                            NaN
# open_il_6m                                             NaN
# open_il_12m                                            NaN
# open_il_24m                                            NaN
# mths_since_rcnt_il                                     NaN
# il_util                                                NaN
# max_bal_bc                                             NaN
# all_util                                               NaN
# total_rev_hi_lim                                       NaN
# inq_fi                                                 NaN
# total_cu_tl                                            NaN
# inq_last_12m                                           NaN
# acc_open_past_24mths                                   NaN
# avg_cur_bal                                            NaN
# chargeoff_within_12_mths                               NaN
# delinq_amnt                                            NaN
# mo_sin_old_il_acct                                     NaN
# mo_sin_old_rev_tl_op                                   NaN
# mo_sin_rcnt_rev_tl_op                                  NaN
# mo_sin_rcnt_tl                                         NaN
# mort_acc                                               NaN
# mths_since_recent_bc                                   NaN
# mths_since_recent_inq                                  NaN
# mths_since_recent_revol_delinq                         NaN
# num_accts_ever_120_pd                                  NaN
# num_bc_sats                                            NaN
# num_il_tl                                              NaN
# num_rev_accts                                          NaN
# num_rev_tl_bal_gt_0                                    NaN
# num_sats                                               NaN
# num_tl_120dpd_2m                                       NaN
# num_tl_30dpd                                           NaN
# num_tl_90g_dpd_24m                                     NaN
# num_tl_op_past_12m                                     NaN
# pct_tl_nvr_dlq                                         NaN
# percent_bc_gt_75                                       NaN
# pub_rec_bankruptcies                                   NaN
# tax_liens                                              NaN
# tot_hi_cred_lim                                        NaN
# total_bc_limit                                         NaN
# total_il_high_credit_limit                             1.0

# %%
df1['const'] = 1
df1.head()
# Out:
#          term  int_rate  installment sub_grade home_ownership  annual_inc  \
# 0   60 months    0.0975       337.99        B3            OWN    120000.0
# 1   36 months    0.0739       186.34        A4       MORTGAGE     72000.0
# 2   36 months    0.1825       204.07        D3       MORTGAGE     53328.0
# 3   36 months    0.1075       195.73        B4           RENT     35000.0
# 4   36 months    0.0839       315.17        B1           RENT     48000.0
#
#   pymnt_plan    dti  delinq_2yrs  inq_last_6mths  pub_rec  total_acc  \
# 0          n  13.68            1             0.0        0         38
# 1          n  10.68            0             0.0        0         18
# 2          n  10.51            0             0.0        0         14
# 3          n  20.58            0             0.0        0          8
# 4          n  29.58            0             0.0        1         17
#
#    mths_since_last_major_derog  policy_code application_type  tot_coll_amt  \
# 0                         53.0            1       INDIVIDUAL           350
# 1                          NaN            1       INDIVIDUAL           157
# 2                          NaN            1       INDIVIDUAL          2124
# 3                          NaN            1       INDIVIDUAL             0
# 4                          NaN            1       INDIVIDUAL           734
#
#    open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  \
# 0          2.0         3.0          2.0          2.0                 2.0
# 1          0.0         5.0          1.0          1.0                 7.0
# 2          3.0         1.0          1.0          3.0                 3.0
# 3          1.0         1.0          0.0          1.0                16.0
# 4          0.0         3.0          0.0          1.0                23.0
#
#    il_util  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0     68.0      4244.0      46.0             54900     5.0          1.0
# 1     87.0      3147.0      55.0             23000     0.0          3.0
# 2     98.0       361.0      65.0              6600     0.0          1.0
# 3     81.0       872.0      80.0              4900     1.0          0.0
# 4     66.0      2987.0      63.0             13600     2.0          4.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  chargeoff_within_12_mths  \
# 0          11.0                    11         4542                         0
# 1           2.0                     4         2052                         0
# 2           0.0                     8        22331                         0
# 3           0.0                     6         3838                         0
# 4           0.0                     3         3255                         0
#
#    delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 0            0               157.0                   256
# 1            0                89.0                    84
# 2            0               121.0                   132
# 3            0                16.0                   130
# 4            0                48.0                    41
#
#    mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                     12               2         1                  14.0
# 1                     14               7         0                  14.0
# 2                      2               2         1                   2.0
# 3                      3               3         0                  10.0
# 4                      7               7         0                  31.0
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    2.0                            20.0
# 1                    9.0                             NaN
# 2                   14.0                            81.0
# 3                   16.0                             NaN
# 4                   18.0                             NaN
#
#    num_accts_ever_120_pd  num_bc_sats  num_il_tl  num_rev_accts  \
# 0                      1            6          8             28
# 1                      0            2          8             10
# 2                      0            3          7              6
# 3                      0            3          1              7
# 4                      0            2          4             13
#
#    num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  num_tl_30dpd  \
# 0                   13        25               0.0             0
# 1                    4        12               0.0             0
# 2                    4         7               0.0             0
# 3                    6         7               0.0             0
# 4                    7        13               0.0             0
#
#    num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                   0                   5            94.6              16.7
# 1                   0                   1           100.0               0.0
# 2                   0                   4            84.6               0.0
# 3                   0                   3           100.0             100.0
# 4                   0                   1           100.0               0.0
#
#    pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bc_limit  \
# 0                     0          0           160515           25000
# 1                     0          0            45139            9400
# 2                     0          0           200449            2600
# 3                     0          0            33626            2100
# 4                     0          0            61807            5800
#
#    total_il_high_credit_limit  const
# 0                       38196      1
# 1                       22139      1
# 2                        7704      1
# 3                       28726      1
# 4                       48207      1

# %%
df2 = df1.dropna(axis=0)

# %%
df2.shape
# Out:
# (61490, 58)

# %%
df2cat = df2[['term', 'sub_grade', 'home_ownership', 'pymnt_plan', 'application_type', 'policy_code']]
df2y = df2[['int_rate']]
df2X = df2.drop(['term', 'sub_grade', 'home_ownership', 'pymnt_plan', 'application_type', 'policy_code', 'int_rate'], axis=1)

# %%
rs1 = sm.OLS(df2y, df2X).fit()
print(rs1.summary())

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               int_rate   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.310
# Method:                 Least Squares   F-statistic:                     552.6
# Date:                Wed, 12 Jul 2017   Prob (F-statistic):               0.00
# Time:                        01:41:08   Log-Likelihood:             1.1074e+05
# No. Observations:               61490   AIC:                        -2.214e+05
# Df Residuals:                   61439   BIC:                        -2.209e+05
# Df Model:                          50
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# installment                     6.299e-05   6.84e-07     92.114      0.000    6.17e-05    6.43e-05
# annual_inc                     -2.756e-08   2.91e-09     -9.467      0.000   -3.33e-08   -2.19e-08
# dti                                0.0012   2.53e-05     49.295      0.000       0.001       0.001
# delinq_2yrs                        0.0021      0.000     10.609      0.000       0.002       0.002
# inq_last_6mths                     0.0055      0.000     24.138      0.000       0.005       0.006
# pub_rec                            0.0008      0.000      1.693      0.090      -0.000       0.002
# total_acc                         -0.0005      0.000     -2.387      0.017      -0.001   -9.79e-05
# mths_since_last_major_derog    -4.747e-05   9.87e-06     -4.810      0.000   -6.68e-05   -2.81e-05
# tot_coll_amt                    1.732e-07   5.03e-08      3.441      0.001    7.45e-08    2.72e-07
# open_acc_6m                        0.0005      0.000      2.718      0.007       0.000       0.001
# open_il_6m                     -2.947e-05      0.000     -0.255      0.799      -0.000       0.000
# open_il_12m                        0.0040      0.000     13.778      0.000       0.003       0.005
# open_il_24m                       -0.0011      0.000     -5.697      0.000      -0.001      -0.001
# mths_since_rcnt_il              3.403e-05   1.11e-05      3.075      0.002    1.23e-05    5.57e-05
# il_util                         7.965e-05   1.28e-05      6.235      0.000    5.46e-05       0.000
# max_bal_bc                     -2.547e-07   6.24e-08     -4.080      0.000   -3.77e-07   -1.32e-07
# all_util                           0.0003    1.8e-05     14.270      0.000       0.000       0.000
# total_rev_hi_lim               -4.716e-08   9.16e-09     -5.149      0.000   -6.51e-08   -2.92e-08
# inq_fi                             0.0003      0.000      2.833      0.005      0.0001       0.001
# total_cu_tl                       -0.0005   6.05e-05     -8.237      0.000      -0.001      -0.000
# inq_last_12m                       0.0005   8.59e-05      6.033      0.000       0.000       0.001
# acc_open_past_24mths               0.0020      0.000     20.307      0.000       0.002       0.002
# avg_cur_bal                     -2.76e-09   2.28e-08     -0.121      0.904   -4.74e-08    4.19e-08
# chargeoff_within_12_mths          -0.0002      0.001     -0.196      0.845      -0.002       0.001
# delinq_amnt                       3.4e-07   1.07e-07      3.163      0.002    1.29e-07    5.51e-07
# mo_sin_old_il_acct             -3.548e-05   3.55e-06     -9.987      0.000   -4.24e-05   -2.85e-05
# mo_sin_old_rev_tl_op            -4.07e-05      2e-06    -20.338      0.000   -4.46e-05   -3.68e-05
# mo_sin_rcnt_rev_tl_op          -2.964e-05   1.56e-05     -1.904      0.057   -6.01e-05    8.65e-07
# mo_sin_rcnt_tl                  7.265e-05   3.77e-05      1.929      0.054   -1.19e-06       0.000
# mort_acc                          -0.0006      0.000     -2.373      0.018      -0.001      -0.000
# mths_since_recent_bc           -5.984e-05   6.25e-06     -9.582      0.000   -7.21e-05   -4.76e-05
# mths_since_recent_inq             -0.0003   3.65e-05     -9.582      0.000      -0.000      -0.000
# mths_since_recent_revol_delinq -6.161e-05    9.5e-06     -6.486      0.000   -8.02e-05    -4.3e-05
# num_accts_ever_120_pd              0.0003   9.56e-05      2.810      0.005    8.12e-05       0.000
# num_bc_sats                        0.0008      0.000      6.535      0.000       0.001       0.001
# num_il_tl                          0.0002      0.000      1.026      0.305      -0.000       0.001
# num_rev_accts                  -9.238e-05      0.000     -0.402      0.688      -0.001       0.000
# num_rev_tl_bal_gt_0             -2.41e-05   9.41e-05     -0.256      0.798      -0.000       0.000
# num_sats                          -0.0005   9.05e-05     -5.108      0.000      -0.001      -0.000
# num_tl_120dpd_2m                   0.0065      0.003      2.216      0.027       0.001       0.012
# num_tl_30dpd                       0.0152      0.002      7.109      0.000       0.011       0.019
# num_tl_90g_dpd_24m                -0.0008      0.000     -2.859      0.004      -0.001      -0.000
# num_tl_op_past_12m                 0.0019      0.000     11.072      0.000       0.002       0.002
# pct_tl_nvr_dlq                  3.269e-05   2.02e-05      1.618      0.106   -6.91e-06    7.23e-05
# percent_bc_gt_75                   0.0002   5.56e-06     27.811      0.000       0.000       0.000
# pub_rec_bankruptcies               0.0026      0.001      4.057      0.000       0.001       0.004
# tax_liens                         -0.0007      0.001     -1.125      0.261      -0.002       0.000
# tot_hi_cred_lim                -8.384e-09   2.12e-09     -3.962      0.000   -1.25e-08   -4.24e-09
# total_bc_limit                 -3.863e-07   2.34e-08    -16.538      0.000   -4.32e-07   -3.41e-07
# total_il_high_credit_limit     -7.518e-08   5.16e-09    -14.567      0.000   -8.53e-08   -6.51e-08
# const                              0.0835      0.002     39.962      0.000       0.079       0.088
# ==============================================================================
# Omnibus:                     6155.638   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8446.923
# Skew:                           0.815   Prob(JB):                         0.00
# Kurtosis:                       3.801   Cond. No.                     4.99e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.99e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
rs2 = sm.OLS.from_formula('int_rate ~ installment + annual_inc + dti + delinq_2yrs + inq_last_6mths + total_acc + mths_since_last_major_derog + open_acc_6m + open_il_12m + open_il_24m + mths_since_rcnt_il + il_util + max_bal_bc + all_util + total_rev_hi_lim + inq_fi + total_cu_tl + inq_last_12m + acc_open_past_24mths + delinq_amnt + mo_sin_old_il_acct + mo_sin_old_rev_tl_op + mort_acc + mths_since_recent_bc + mths_since_recent_inq + mths_since_recent_revol_delinq + num_accts_ever_120_pd + num_bc_sats + num_sats + num_tl_30dpd + num_tl_90g_dpd_24m + num_tl_op_past_12m + percent_bc_gt_75 + pub_rec_bankruptcies + tot_hi_cred_lim + total_bc_limit + total_il_high_credit_limit', df2).fit()
print(rs2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               int_rate   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     743.3
# Date:                Wed, 12 Jul 2017   Prob (F-statistic):               0.00
# Time:                        02:12:13   Log-Likelihood:             1.1069e+05
# No. Observations:               61490   AIC:                        -2.213e+05
# Df Residuals:                   61452   BIC:                        -2.210e+05
# Df Model:                          37
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.0857      0.001     68.710      0.000       0.083       0.088
# installment                     6.274e-05   6.82e-07     91.952      0.000    6.14e-05    6.41e-05
# annual_inc                     -2.893e-08    2.9e-09     -9.992      0.000   -3.46e-08   -2.33e-08
# dti                                0.0012   2.48e-05     49.475      0.000       0.001       0.001
# delinq_2yrs                        0.0020      0.000     10.481      0.000       0.002       0.002
# inq_last_6mths                     0.0056      0.000     24.249      0.000       0.005       0.006
# total_acc                         -0.0005    2.3e-05    -19.821      0.000      -0.001      -0.000
# mths_since_last_major_derog    -4.742e-05   9.79e-06     -4.844      0.000   -6.66e-05   -2.82e-05
# open_acc_6m                        0.0005      0.000      2.451      0.014    9.34e-05       0.001
# open_il_12m                        0.0039      0.000     13.404      0.000       0.003       0.004
# open_il_24m                       -0.0008      0.000     -4.065      0.000      -0.001      -0.000
# mths_since_rcnt_il              4.095e-05   1.08e-05      3.798      0.000    1.98e-05    6.21e-05
# il_util                         7.409e-05   1.25e-05      5.943      0.000    4.97e-05    9.85e-05
# max_bal_bc                     -2.776e-07    6.2e-08     -4.477      0.000   -3.99e-07   -1.56e-07
# all_util                           0.0003   1.66e-05     16.570      0.000       0.000       0.000
# total_rev_hi_lim               -5.353e-08   9.03e-09     -5.931      0.000   -7.12e-08   -3.58e-08
# inq_fi                             0.0003      0.000      2.971      0.003       0.000       0.001
# total_cu_tl                       -0.0005   6.01e-05     -7.703      0.000      -0.001      -0.000
# inq_last_12m                       0.0005   8.58e-05      6.025      0.000       0.000       0.001
# acc_open_past_24mths               0.0019   9.76e-05     19.909      0.000       0.002       0.002
# delinq_amnt                     4.318e-07   9.98e-08      4.328      0.000    2.36e-07    6.27e-07
# mo_sin_old_il_acct             -3.076e-05   3.49e-06     -8.818      0.000   -3.76e-05   -2.39e-05
# mo_sin_old_rev_tl_op           -4.495e-05    1.9e-06    -23.599      0.000   -4.87e-05   -4.12e-05
# mort_acc                          -0.0008      0.000     -7.116      0.000      -0.001      -0.001
# mths_since_recent_bc            -6.41e-05   5.46e-06    -11.733      0.000   -7.48e-05   -5.34e-05
# mths_since_recent_inq             -0.0003   3.62e-05     -9.431      0.000      -0.000      -0.000
# mths_since_recent_revol_delinq -5.621e-05   9.44e-06     -5.957      0.000   -7.47e-05   -3.77e-05
# num_accts_ever_120_pd              0.0002   8.01e-05      2.734      0.006     6.2e-05       0.000
# num_bc_sats                        0.0006      0.000      5.818      0.000       0.000       0.001
# num_sats                          -0.0005   5.26e-05     -9.538      0.000      -0.001      -0.000
# num_tl_30dpd                       0.0151      0.002      7.046      0.000       0.011       0.019
# num_tl_90g_dpd_24m                -0.0007      0.000     -2.500      0.012      -0.001      -0.000
# num_tl_op_past_12m                 0.0019      0.000     11.276      0.000       0.002       0.002
# percent_bc_gt_75                   0.0002   5.46e-06     27.904      0.000       0.000       0.000
# pub_rec_bankruptcies               0.0032      0.000      6.945      0.000       0.002       0.004
# tot_hi_cred_lim                -8.636e-09   1.26e-09     -6.833      0.000   -1.11e-08   -6.16e-09
# total_bc_limit                 -3.741e-07   2.28e-08    -16.418      0.000   -4.19e-07   -3.29e-07
# total_il_high_credit_limit      -6.33e-08   4.83e-09    -13.119      0.000   -7.28e-08   -5.38e-08
# ==============================================================================
# Omnibus:                     6137.968   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8413.064
# Skew:                           0.814   Prob(JB):                         0.00
# Kurtosis:                       3.798   Cond. No.                     3.63e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.63e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
rs3 = sm.OLS.from_formula('int_rate ~ sub_grade + 0', df2).fit()
print(rs3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               int_rate   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 9.244e+04
# Date:                Wed, 12 Jul 2017   Prob (F-statistic):               0.00
# Time:                        02:00:28   Log-Likelihood:             2.2088e+05
# No. Observations:               61490   AIC:                        -4.417e+05
# Df Residuals:                   61455   BIC:                        -4.414e+05
# Df Model:                          34
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# sub_grade[A1]     0.0532      0.000    273.821      0.000       0.053       0.054
# sub_grade[A2]     0.0668      0.000    288.293      0.000       0.066       0.067
# sub_grade[A3]     0.0717      0.000    330.005      0.000       0.071       0.072
# sub_grade[A4]     0.0751      0.000    443.274      0.000       0.075       0.075
# sub_grade[A5]     0.0808      0.000    513.068      0.000       0.081       0.081
# sub_grade[B1]     0.0854      0.000    739.238      0.000       0.085       0.086
# sub_grade[B2]     0.0949      0.000    831.739      0.000       0.095       0.095
# sub_grade[B3]     0.1026      0.000    927.753      0.000       0.102       0.103
# sub_grade[B4]     0.1096      0.000   1071.471      0.000       0.109       0.110
# sub_grade[B5]     0.1148    9.6e-05   1195.709      0.000       0.115       0.115
# sub_grade[C1]     0.1243   9.55e-05   1301.434      0.000       0.124       0.124
# sub_grade[C2]     0.1325      0.000   1273.995      0.000       0.132       0.133
# sub_grade[C3]     0.1382      0.000   1293.704      0.000       0.138       0.138
# sub_grade[C4]     0.1454      0.000   1377.855      0.000       0.145       0.146
# sub_grade[C5]     0.1552      0.000   1400.932      0.000       0.155       0.155
# sub_grade[D1]     0.1661      0.000   1203.701      0.000       0.166       0.166
# sub_grade[D2]     0.1765      0.000   1264.842      0.000       0.176       0.177
# sub_grade[D3]     0.1860      0.000   1157.230      0.000       0.186       0.186
# sub_grade[D4]     0.1945      0.000   1159.655      0.000       0.194       0.195
# sub_grade[D5]     0.2050      0.000   1129.268      0.000       0.205       0.205
# sub_grade[E1]     0.2128      0.000   1099.385      0.000       0.212       0.213
# sub_grade[E2]     0.2191      0.000    929.261      0.000       0.219       0.220
# sub_grade[E3]     0.2282      0.000   1002.394      0.000       0.228       0.229
# sub_grade[E4]     0.2346      0.000    914.364      0.000       0.234       0.235
# sub_grade[E5]     0.2394      0.000    867.161      0.000       0.239       0.240
# sub_grade[F1]     0.2466      0.000    818.201      0.000       0.246       0.247
# sub_grade[F2]     0.2576      0.000    720.905      0.000       0.257       0.258
# sub_grade[F3]     0.2618      0.000    624.836      0.000       0.261       0.263
# sub_grade[F4]     0.2672      0.000    613.206      0.000       0.266       0.268
# sub_grade[F5]     0.2754      0.000    563.566      0.000       0.274       0.276
# sub_grade[G1]     0.2806      0.001    433.392      0.000       0.279       0.282
# sub_grade[G2]     0.2878      0.001    448.758      0.000       0.287       0.289
# sub_grade[G3]     0.2887      0.001    399.315      0.000       0.287       0.290
# sub_grade[G4]     0.2931      0.001    337.707      0.000       0.291       0.295
# sub_grade[G5]     0.2997      0.001    287.860      0.000       0.298       0.302
# ==============================================================================
# Omnibus:                    43800.490   Durbin-Watson:                   1.237
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15220249.222
# Skew:                          -2.301   Prob(JB):                         0.00
# Kurtosis:                      79.938   Cond. No.                         10.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df2['resid'] = df2.int_rate - rs3.predict()
df2.resid.head()
# Out:
# C:\Users\Ryoo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0    -0.005054
# 10   -0.002102
# 24   -0.004355
# 32   -0.002591
# 38   -0.001488
# Name: resid, dtype: float64

# %%
rs2 = sm.OLS.from_formula('resid ~ installment + annual_inc + dti + delinq_2yrs + inq_last_6mths + total_acc + mths_since_last_major_derog + open_acc_6m + open_il_12m + open_il_24m + mths_since_rcnt_il + il_util + max_bal_bc + all_util + total_rev_hi_lim + inq_fi + total_cu_tl + inq_last_12m + acc_open_past_24mths + delinq_amnt + mo_sin_old_il_acct + mo_sin_old_rev_tl_op + mort_acc + mths_since_recent_bc + mths_since_recent_inq + mths_since_recent_revol_delinq + num_accts_ever_120_pd + num_bc_sats + num_sats + num_tl_30dpd + num_tl_90g_dpd_24m + num_tl_op_past_12m + percent_bc_gt_75 + pub_rec_bankruptcies + tot_hi_cred_lim + total_bc_limit + total_il_high_credit_limit', df2).fit()
print(rs2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  resid   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     13.77
# Date:                Wed, 12 Jul 2017   Prob (F-statistic):           5.02e-84
# Time:                        02:11:45   Log-Likelihood:             2.2114e+05
# No. Observations:               61490   AIC:                        -4.422e+05
# Df Residuals:                   61452   BIC:                        -4.419e+05
# Df Model:                          37
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.0017      0.000      8.272      0.000       0.001       0.002
# installment                    -1.023e-07   1.13e-07     -0.904      0.366   -3.24e-07     1.2e-07
# annual_inc                     -9.378e-10    4.8e-10     -1.952      0.051   -1.88e-09    3.88e-12
# dti                            -3.173e-05   4.11e-06     -7.726      0.000   -3.98e-05   -2.37e-05
# delinq_2yrs                     1.435e-05   3.15e-05      0.455      0.649   -4.74e-05    7.61e-05
# inq_last_6mths                 -9.993e-05    3.8e-05     -2.629      0.009      -0.000   -2.54e-05
# total_acc                      -2.009e-05   3.81e-06     -5.268      0.000   -2.76e-05   -1.26e-05
# mths_since_last_major_derog    -1.269e-06   1.62e-06     -0.781      0.435   -4.45e-06    1.91e-06
# open_acc_6m                       -0.0001   3.16e-05     -3.690      0.000      -0.000   -5.46e-05
# open_il_12m                       -0.0004    4.8e-05     -8.934      0.000      -0.001      -0.000
# open_il_24m                        0.0002   3.07e-05      7.547      0.000       0.000       0.000
# mths_since_rcnt_il             -4.119e-06   1.79e-06     -2.302      0.021   -7.62e-06   -6.12e-07
# il_util                         2.299e-06   2.07e-06      1.111      0.266   -1.76e-06    6.35e-06
# max_bal_bc                      4.148e-09   1.03e-08      0.403      0.687    -1.6e-08    2.43e-08
# all_util                       -8.022e-06   2.76e-06     -2.907      0.004   -1.34e-05   -2.61e-06
# total_rev_hi_lim                -2.38e-09    1.5e-09     -1.589      0.112   -5.32e-09    5.55e-10
# inq_fi                          5.076e-05    1.9e-05      2.673      0.008    1.35e-05     8.8e-05
# total_cu_tl                    -1.732e-06   9.98e-06     -0.174      0.862   -2.13e-05    1.78e-05
# inq_last_12m                   -7.538e-05   1.42e-05     -5.292      0.000      -0.000   -4.75e-05
# acc_open_past_24mths           -1.464e-06   1.62e-05     -0.090      0.928   -3.32e-05    3.03e-05
# delinq_amnt                    -1.078e-08   1.66e-08     -0.651      0.515   -4.32e-08    2.17e-08
# mo_sin_old_il_acct               7.77e-07   5.79e-07      1.342      0.180   -3.58e-07    1.91e-06
# mo_sin_old_rev_tl_op            1.214e-06   3.16e-07      3.842      0.000    5.95e-07    1.83e-06
# mort_acc                          -0.0001   1.75e-05     -7.109      0.000      -0.000   -9.03e-05
# mths_since_recent_bc           -4.997e-07   9.07e-07     -0.551      0.582   -2.28e-06    1.28e-06
# mths_since_recent_inq          -2.686e-05   6.01e-06     -4.471      0.000   -3.86e-05   -1.51e-05
# mths_since_recent_revol_delinq -2.754e-06   1.57e-06     -1.759      0.079   -5.82e-06    3.15e-07
# num_accts_ever_120_pd            3.82e-05   1.33e-05      2.875      0.004    1.22e-05    6.42e-05
# num_bc_sats                     -7.65e-06   1.78e-05     -0.430      0.667   -4.25e-05    2.72e-05
# num_sats                        2.351e-05   8.72e-06      2.695      0.007    6.41e-06    4.06e-05
# num_tl_30dpd                      -0.0006      0.000     -1.644      0.100      -0.001       0.000
# num_tl_90g_dpd_24m             -2.229e-05   4.75e-05     -0.469      0.639      -0.000    7.09e-05
# num_tl_op_past_12m              1.635e-05   2.84e-05      0.576      0.565   -3.93e-05     7.2e-05
# percent_bc_gt_75               -1.089e-06   9.06e-07     -1.202      0.229   -2.86e-06    6.87e-07
# pub_rec_bankruptcies              -0.0003   7.59e-05     -4.608      0.000      -0.000      -0.000
# tot_hi_cred_lim                 5.961e-10    2.1e-10      2.843      0.004    1.85e-10    1.01e-09
# total_bc_limit                  6.818e-09   3.78e-09      1.803      0.071   -5.92e-10    1.42e-08
# total_il_high_credit_limit       3.99e-10   8.01e-10      0.498      0.618   -1.17e-09    1.97e-09
# ==============================================================================
# Omnibus:                    43192.936   Durbin-Watson:                   1.252
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15332876.485
# Skew:                          -2.238   Prob(JB):                         0.00
# Kurtosis:                      80.230   Cond. No.                     3.63e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.63e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
