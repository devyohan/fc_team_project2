# %%
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import matplotlib as mlt
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Out:
# C:\Users\Ryoo\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df0 = pd.read_csv('lcdf3.csv')

# %%
df0.head()
# Out:
#    loan_amnt        term  int_rate  installment sub_grade home_ownership  \
# 0      16000   60 months    0.0975       337.99        B3            OWN
# 1       6000   36 months    0.0739       186.34        A4       MORTGAGE
# 2       5625   36 months    0.1825       204.07        D3       MORTGAGE
# 3       6000   36 months    0.1075       195.73        B4           RENT
# 4      10000   36 months    0.0839       315.17        B1           RENT
#
#    annual_inc pymnt_plan    dti  delinq_2yrs             ...              \
# 0    120000.0          n  13.68            1             ...
# 1     72000.0          n  10.68            0             ...
# 2     53328.0          n  10.51            0             ...
# 3     35000.0          n  20.58            0             ...
# 4     48000.0          n  29.58            0             ...
#
#    num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                   0                   5            94.6              16.7
# 1                   0                   1           100.0               0.0
# 2                   0                   4            84.6               0.0
# 3                   0                   3           100.0             100.0
# 4                   0                   1           100.0               0.0
#
#    pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 0                     0          0           160515              42544
# 1                     0          0            45139              24618
# 2                     0          0           200449               9333
# 3                     0          0            33626              26867
# 4                     0          0            61807              39061
#
#    total_bc_limit  total_il_high_credit_limit
# 0           25000                       38196
# 1            9400                       22139
# 2            2600                        7704
# 3            2100                       28726
# 4            5800                       48207
#
# [5 rows x 87 columns]

# %%
pd.options.display.max_rows=100
df0.isnull().sum()
# Out:
# loan_amnt                              0
# term                                   0
# int_rate                               0
# installment                            0
# sub_grade                              0
# home_ownership                         0
# annual_inc                             0
# pymnt_plan                             0
# dti                                    0
# delinq_2yrs                            0
# inq_last_6mths                         0
# mths_since_last_delinq            191309
# mths_since_last_record            331910
# open_acc                               0
# pub_rec                                0
# revol_bal                              0
# revol_util                             0
# total_acc                              0
# out_prncp                              0
# out_prncp_inv                          0
# total_pymnt                            0
# total_pymnt_inv                        0
# total_rec_prncp                        0
# total_rec_int                          0
# total_rec_late_fee                     0
# recoveries                             0
# collection_recovery_fee                0
# last_pymnt_amnt                        0
# collections_12_mths_ex_med             0
# mths_since_last_major_derog       290372
# policy_code                            0
# application_type                       0
# acc_now_delinq                         0
# tot_coll_amt                           0
# tot_cur_bal                            0
# open_acc_6m                            0
# open_il_6m                             0
# open_il_12m                            0
# open_il_24m                            0
# mths_since_rcnt_il                     0
# total_bal_il                           0
# il_util                            45144
# open_rv_12m                            0
# open_rv_24m                            0
# max_bal_bc                             0
# all_util                               0
# total_rev_hi_lim                       0
# inq_fi                                 0
# total_cu_tl                            0
# inq_last_12m                           0
# acc_open_past_24mths                   0
# avg_cur_bal                            0
# bc_open_to_buy                      4211
# bc_util                             4370
# chargeoff_within_12_mths               0
# delinq_amnt                            0
# mo_sin_old_il_acct                     0
# mo_sin_old_rev_tl_op                   0
# mo_sin_rcnt_rev_tl_op                  0
# mo_sin_rcnt_tl                         0
# mort_acc                               0
# mths_since_recent_bc                3976
# mths_since_recent_bc_dlq          304904
# mths_since_recent_inq              42022
# mths_since_recent_revol_delinq    260606
# num_accts_ever_120_pd                  0
# num_actv_bc_tl                         0
# num_actv_rev_tl                        0
# num_bc_sats                            0
# num_bc_tl                              0
# num_il_tl                              0
# num_op_rev_tl                          0
# num_rev_accts                          0
# num_rev_tl_bal_gt_0                    0
# num_sats                               0
# num_tl_120dpd_2m                   20785
# num_tl_30dpd                           0
# num_tl_90g_dpd_24m                     0
# num_tl_op_past_12m                     0
# pct_tl_nvr_dlq                         0
# percent_bc_gt_75                    4241
# pub_rec_bankruptcies                   0
# tax_liens                              0
# tot_hi_cred_lim                        0
# total_bal_ex_mort                      0
# total_bc_limit                         0
# total_il_high_credit_limit             0
# dtype: int64

# %%
md1 = sm.OLS.from_formula('int_rate ~ acc_open_past_24mths + avg_cur_bal + tot_hi_cred_lim + total_bal_ex_mort + total_bc_limit + total_il_high_credit_limit + annual_inc + avg_cur_bal + total_rev_hi_lim + total_bal_il + tot_cur_bal + revol_bal', df0)
rs1 = md1.fit()
print(rs1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               int_rate   R-squared:                       0.152
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     6674.
# Date:                Tue, 11 Jul 2017   Prob (F-statistic):               0.00
# Time:                        21:14:26   Log-Likelihood:             6.8852e+05
# No. Observations:              410907   AIC:                        -1.377e+06
# Df Residuals:                  410895   BIC:                        -1.377e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1244      0.000    728.035      0.000       0.124       0.125
# acc_open_past_24mths           0.0043   2.32e-05    183.557      0.000       0.004       0.004
# avg_cur_bal                -6.152e-08   8.99e-09     -6.846      0.000   -7.91e-08   -4.39e-08
# tot_hi_cred_lim            -8.404e-09   1.98e-09     -4.243      0.000   -1.23e-08   -4.52e-09
# total_bal_ex_mort           2.024e-07   8.22e-09     24.621      0.000    1.86e-07    2.18e-07
# total_bc_limit             -3.145e-08   5.88e-09     -5.349      0.000    -4.3e-08   -1.99e-08
# total_il_high_credit_limit -1.451e-07   5.99e-09    -24.224      0.000   -1.57e-07   -1.33e-07
# annual_inc                 -2.502e-08   1.01e-09    -24.785      0.000    -2.7e-08    -2.3e-08
# total_rev_hi_lim           -7.087e-07   6.26e-09   -113.245      0.000   -7.21e-07   -6.96e-07
# total_bal_il               -1.488e-08   1.02e-08     -1.466      0.143   -3.48e-08    5.02e-09
# tot_cur_bal                 -1.31e-08   2.35e-09     -5.573      0.000   -1.77e-08    -8.5e-09
# revol_bal                   7.349e-07   9.68e-09     75.894      0.000    7.16e-07    7.54e-07
# ==============================================================================
# Omnibus:                    65467.114   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           123893.972
# Skew:                           1.001   Prob(JB):                         0.00
# Kurtosis:                       4.797   Cond. No.                     8.73e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# 로그 취한 종속변수 추가
df0['log_int_rate'] = np.log(df0.int_rate)

# %%
df0['trhl'] = df0['total_rev_hi_lim'] / (df0['num_rev_accts'] + 1) 
df0['tbl'] = df0['total_bc_limit'] / (df0['num_bc_tl'] + 1) 
df0['tihcl'] = df0['total_il_high_credit_limit'] / (df0['num_il_tl'] + 1)

# %%
md1 = sm.OLS.from_formula('log_int_rate ~ acc_open_past_24mths + avg_cur_bal + tot_hi_cred_lim + total_bal_ex_mort + tbl + tihcl + trhl+ annual_inc + avg_cur_bal + total_bal_il + tot_cur_bal + revol_bal', df0)
rs1 = md1.fit()
print(rs1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           log_int_rate   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     5848.
# Date:                Tue, 11 Jul 2017   Prob (F-statistic):               0.00
# Time:                        21:14:27   Log-Likelihood:            -1.5240e+05
# No. Observations:              410907   AIC:                         3.048e+05
# Df Residuals:                  410895   BIC:                         3.050e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -2.1343      0.001  -1477.813      0.000      -2.137      -2.132
# acc_open_past_24mths     0.0263      0.000    148.346      0.000       0.026       0.027
# avg_cur_bal           2.126e-06   7.03e-08     30.245      0.000    1.99e-06    2.26e-06
# tot_hi_cred_lim      -1.166e-06   1.34e-08    -87.139      0.000   -1.19e-06   -1.14e-06
# total_bal_ex_mort     1.854e-06   6.34e-08     29.246      0.000    1.73e-06    1.98e-06
# tbl                  -2.601e-05   4.08e-07    -63.683      0.000   -2.68e-05   -2.52e-05
# tihcl                 5.262e-06   1.52e-07     34.599      0.000    4.96e-06    5.56e-06
# trhl                 -1.519e-05   5.09e-07    -29.843      0.000   -1.62e-05   -1.42e-05
# annual_inc           -2.367e-07   7.74e-09    -30.581      0.000   -2.52e-07   -2.22e-07
# total_bal_il         -1.576e-06   6.54e-08    -24.108      0.000    -1.7e-06   -1.45e-06
# tot_cur_bal           7.759e-07   1.74e-08     44.692      0.000    7.42e-07     8.1e-07
# revol_bal             1.041e-06   6.43e-08     16.196      0.000    9.15e-07    1.17e-06
# ==============================================================================
# Omnibus:                    75643.548   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1431920.615
# Skew:                           0.354   Prob(JB):                         0.00
# Kurtosis:                      12.118   Cond. No.                     9.37e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.37e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sm.statsmd1 = sm.OLS.from_formula('int_rate ~ C(home_ownership) + delinq_2yrs + pct_tl_nvr_dlq + acc_open_past_24mths + avg_cur_bal + tot_hi_cred_lim + total_bal_ex_mort + tbl + tihcl + trhl+ annual_inc + avg_cur_bal + total_bal_il + tot_cur_bal + revol_bal', df0)
rs1 = md1.fit()
print(rs1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           log_int_rate   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     5848.
# Date:                Tue, 11 Jul 2017   Prob (F-statistic):               0.00
# Time:                        21:14:28   Log-Likelihood:            -1.5240e+05
# No. Observations:              410907   AIC:                         3.048e+05
# Df Residuals:                  410895   BIC:                         3.050e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -2.1343      0.001  -1477.813      0.000      -2.137      -2.132
# acc_open_past_24mths     0.0263      0.000    148.346      0.000       0.026       0.027
# avg_cur_bal           2.126e-06   7.03e-08     30.245      0.000    1.99e-06    2.26e-06
# tot_hi_cred_lim      -1.166e-06   1.34e-08    -87.139      0.000   -1.19e-06   -1.14e-06
# total_bal_ex_mort     1.854e-06   6.34e-08     29.246      0.000    1.73e-06    1.98e-06
# tbl                  -2.601e-05   4.08e-07    -63.683      0.000   -2.68e-05   -2.52e-05
# tihcl                 5.262e-06   1.52e-07     34.599      0.000    4.96e-06    5.56e-06
# trhl                 -1.519e-05   5.09e-07    -29.843      0.000   -1.62e-05   -1.42e-05
# annual_inc           -2.367e-07   7.74e-09    -30.581      0.000   -2.52e-07   -2.22e-07
# total_bal_il         -1.576e-06   6.54e-08    -24.108      0.000    -1.7e-06   -1.45e-06
# tot_cur_bal           7.759e-07   1.74e-08     44.692      0.000    7.42e-07     8.1e-07
# revol_bal             1.041e-06   6.43e-08     16.196      0.000    9.15e-07    1.17e-06
# ==============================================================================
# Omnibus:                    75643.548   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1431920.615
# Skew:                           0.354   Prob(JB):                         0.00
# Kurtosis:                      12.118   Cond. No.                     9.37e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.37e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sm.statsmd1 = sm.OLS.from_formula('int_rate ~ term + C(home_ownership) + delinq_2yrs + pct_tl_nvr_dlq + acc_open_past_24mths + avg_cur_bal + tot_hi_cred_lim + total_bal_ex_mort + tbl + tihcl + trhl+ annual_inc + avg_cur_bal + total_bal_il + tot_cur_bal + revol_bal + 0', df0)
rs1 = md1.fit()
print(rs1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           log_int_rate   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     5848.
# Date:                Tue, 11 Jul 2017   Prob (F-statistic):               0.00
# Time:                        21:14:32   Log-Likelihood:            -1.5240e+05
# No. Observations:              410907   AIC:                         3.048e+05
# Df Residuals:                  410895   BIC:                         3.050e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -2.1343      0.001  -1477.813      0.000      -2.137      -2.132
# acc_open_past_24mths     0.0263      0.000    148.346      0.000       0.026       0.027
# avg_cur_bal           2.126e-06   7.03e-08     30.245      0.000    1.99e-06    2.26e-06
# tot_hi_cred_lim      -1.166e-06   1.34e-08    -87.139      0.000   -1.19e-06   -1.14e-06
# total_bal_ex_mort     1.854e-06   6.34e-08     29.246      0.000    1.73e-06    1.98e-06
# tbl                  -2.601e-05   4.08e-07    -63.683      0.000   -2.68e-05   -2.52e-05
# tihcl                 5.262e-06   1.52e-07     34.599      0.000    4.96e-06    5.56e-06
# trhl                 -1.519e-05   5.09e-07    -29.843      0.000   -1.62e-05   -1.42e-05
# annual_inc           -2.367e-07   7.74e-09    -30.581      0.000   -2.52e-07   -2.22e-07
# total_bal_il         -1.576e-06   6.54e-08    -24.108      0.000    -1.7e-06   -1.45e-06
# tot_cur_bal           7.759e-07   1.74e-08     44.692      0.000    7.42e-07     8.1e-07
# revol_bal             1.041e-06   6.43e-08     16.196      0.000    9.15e-07    1.17e-06
# ==============================================================================
# Omnibus:                    75643.548   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1431920.615
# Skew:                           0.354   Prob(JB):                         0.00
# Kurtosis:                      12.118   Cond. No.                     9.37e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.37e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df1 = pd.read_csv('lcdf4.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  loan_amnt        term  int_rate  installment sub_grade  \
# 0           0   0.384615   60 months  0.172575     0.198015        B3
# 1           1   0.128205   36 months  0.080639     0.100477        A4
# 2           2   0.118590   36 months  0.503701     0.111881        D3
# 3           3   0.128205   36 months  0.211531     0.106517        B4
# 4           4   0.230769   36 months  0.119595     0.183338        B1
#
#   home_ownership  annual_inc pymnt_plan       dti             ...              \
# 0            OWN    0.012019          n  0.358136             ...
# 1       MORTGAGE    0.007002          n  0.284948             ...
# 2       MORTGAGE    0.005051          n  0.280800             ...
# 3           RENT    0.003135          n  0.526470             ...
# 4           RENT    0.004494          n  0.746036             ...
#
#    num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                   0                   5           0.946              16.7
# 1                   0                   1           1.000               0.0
# 2                   0                   4           0.846               0.0
# 3                   0                   3           1.000             100.0
# 4                   0                   1           1.000               0.0
#
#    pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 0                     0          0         0.015805           0.027481
# 1                     0          0         0.004265           0.015902
# 2                     0          0         0.019800           0.006029
# 3                     0          0         0.003113           0.017355
# 4                     0          0         0.005932           0.025231
#
#    total_bc_limit  total_il_high_credit_limit
# 0        0.022614                    0.019098
# 1        0.008503                    0.011069
# 2        0.002352                    0.003852
# 3        0.001900                    0.014363
# 4        0.005246                    0.024103
#
# [5 rows x 88 columns]

# %%
del df1['Unnamed: 0']

# %%
md1 = sm.OLS.from_formula('int_rate ~ C(term) + acc_open_past_24mths + avg_cur_bal + total_bal_ex_mort + total_bc_limit + total_il_high_credit_limit + annual_inc + avg_cur_bal + total_rev_hi_lim + tot_cur_bal + revol_bal + 0', df1)
rs1 = md1.fit()
print(rs1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               int_rate   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                 1.808e+04
# Date:                Tue, 11 Jul 2017   Prob (F-statistic):               0.00
# Time:                        21:14:39   Log-Likelihood:             1.7091e+05
# No. Observations:              410907   AIC:                        -3.418e+05
# Df Residuals:                  410896   BIC:                        -3.417e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# C(term)[ 36 months]            0.2462      0.001    407.778      0.000       0.245       0.247
# C(term)[ 60 months]            0.4201      0.001    551.568      0.000       0.419       0.422
# acc_open_past_24mths           0.0162   8.15e-05    198.659      0.000       0.016       0.016
# avg_cur_bal                   -0.2370      0.024     -9.942      0.000      -0.284      -0.190
# total_bal_ex_mort              1.2401      0.026     46.840      0.000       1.188       1.292
# total_bc_limit                -0.3876      0.023    -17.098      0.000      -0.432      -0.343
# total_il_high_credit_limit    -1.4477      0.034    -42.857      0.000      -1.514      -1.382
# annual_inc                    -0.9757      0.034    -28.913      0.000      -1.042      -0.910
# total_rev_hi_lim              -4.2866      0.034   -126.667      0.000      -4.353      -4.220
# tot_cur_bal                   -0.5696      0.020    -28.771      0.000      -0.608      -0.531
# revol_bal                      2.7689      0.028    100.409      0.000       2.715       2.823
# ==============================================================================
# Omnibus:                    59905.187   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           120559.669
# Skew:                           0.902   Prob(JB):                         0.00
# Kurtosis:                       4.946   Cond. No.                     1.13e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
rs2 = sm.OLS.from_formula('int_rate ~ sub_grade + 0', df1).fit()
print(rs2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               int_rate   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 7.640e+05
# Date:                Tue, 11 Jul 2017   Prob (F-statistic):               0.00
# Time:                        21:14:44   Log-Likelihood:             9.5115e+05
# No. Observations:              410907   AIC:                        -1.902e+06
# Df Residuals:                  410872   BIC:                        -1.902e+06
# Df Model:                          34
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# sub_grade[A1]          0      0.000          0      1.000      -0.000       0.000
# sub_grade[A2]     0.0534      0.000    228.277      0.000       0.053       0.054
# sub_grade[A3]     0.0720      0.000    296.340      0.000       0.071       0.072
# sub_grade[A4]     0.0858      0.000    428.761      0.000       0.085       0.086
# sub_grade[A5]     0.1073      0.000    566.638      0.000       0.107       0.108
# sub_grade[B1]     0.1253      0.000    805.100      0.000       0.125       0.126
# sub_grade[B2]     0.1624      0.000   1024.010      0.000       0.162       0.163
# sub_grade[B3]     0.1919      0.000   1262.307      0.000       0.192       0.192
# sub_grade[B4]     0.2197      0.000   1524.553      0.000       0.219       0.220
# sub_grade[B5]     0.2400      0.000   1728.860      0.000       0.240       0.240
# sub_grade[C1]     0.2762      0.000   1995.861      0.000       0.276       0.276
# sub_grade[C2]     0.3087      0.000   2043.400      0.000       0.308       0.309
# sub_grade[C3]     0.3311      0.000   2137.932      0.000       0.331       0.331
# sub_grade[C4]     0.3594      0.000   2341.404      0.000       0.359       0.360
# sub_grade[C5]     0.3977      0.000   2438.037      0.000       0.397       0.398
# sub_grade[D1]     0.4393      0.000   2187.704      0.000       0.439       0.440
# sub_grade[D2]     0.4805      0.000   2317.152      0.000       0.480       0.481
# sub_grade[D3]     0.5178      0.000   2170.754      0.000       0.517       0.518
# sub_grade[D4]     0.5501      0.000   2266.767      0.000       0.550       0.551
# sub_grade[D5]     0.5931      0.000   2190.087      0.000       0.593       0.594
# sub_grade[E1]     0.6200      0.000   2149.531      0.000       0.619       0.621
# sub_grade[E2]     0.6466      0.000   1836.778      0.000       0.646       0.647
# sub_grade[E3]     0.6811      0.000   1975.642      0.000       0.680       0.682
# sub_grade[E4]     0.7072      0.000   1871.112      0.000       0.707       0.708
# sub_grade[E5]     0.7299      0.000   1790.975      0.000       0.729       0.731
# sub_grade[F1]     0.7532      0.000   1619.567      0.000       0.752       0.754
# sub_grade[F2]     0.7902      0.001   1485.565      0.000       0.789       0.791
# sub_grade[F3]     0.8172      0.001   1344.186      0.000       0.816       0.818
# sub_grade[F4]     0.8425      0.001   1258.959      0.000       0.841       0.844
# sub_grade[F5]     0.8671      0.001   1196.427      0.000       0.866       0.869
# sub_grade[G1]     0.8901      0.001    993.515      0.000       0.888       0.892
# sub_grade[G2]     0.9137      0.001    905.272      0.000       0.912       0.916
# sub_grade[G3]     0.9290      0.001    805.834      0.000       0.927       0.931
# sub_grade[G4]     0.9400      0.001    726.141      0.000       0.937       0.943
# sub_grade[G5]     0.9564      0.002    624.947      0.000       0.953       0.959
# ==============================================================================
# Omnibus:                   190590.418   Durbin-Watson:                   1.236
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         38519381.126
# Skew:                          -1.112   Prob(JB):                         0.00
# Kurtosis:                      50.380   Cond. No.                         11.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
